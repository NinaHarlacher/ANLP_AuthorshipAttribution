# %% [markdown]
# # Generative Model with SVM classifier

# %%
import os
import spacy
import numpy as np
import pandas as pd
from glob import glob

from scipy.stats import mode

from sklearn import linear_model
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.datasets import make_classification
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split


import nltk
from nltk.corpus import stopwords
from stop_words import get_stop_words

# %% [markdown]
# ## Preparing Data
#
# We prepare the data such that each sentence of a play is an instance.

# %%
corpus= glob("El/*")
corpus_tagged = glob('Tagged_or_Stopwords/*')

# %%
def get_ordered_lists(auhtors, corpus):
    """ 
    input: corpus as a list with path of files and a list of authors
    
    output: list of list, with the same order of the author list, with a list containing all plays for each author
    """
    dramas_per_author=[]
    for author in auhtors:
        authorList=[]
        for drama in corpus:
            if author in drama:
                authorList.append(drama)
        dramas_per_author.append(authorList)
    
    return dramas_per_author

# %%
def get_lists(corpus, auhtors):
    
    """
    input: list of authors, list of all files as paths for all plays
    
    output: list with  all files ordered according to author list 
    """
    corpus_per_author = get_ordered_lists(auhtors, corpus)
    
    data=[]
    labels=[]
    for idx, corpus in enumerate(corpus_per_author):
        for idx2, play in enumerate(corpus):
            instance= play
            data.append(instance)

            labels.append(idx)


    
    return data, labels


y_authors = ['E-Shakespeare', 'L-Shakespeare', 'Marlowe', 'Middleton','Jonson', 'Chapman']

data, labels = get_lists(corpus, y_authors)

# %% [markdown]
# ### Preparing stop word lists

# %%
nlp = spacy.load("en")
stopwrd1= []
for word in nlp.Defaults.stop_words:
    stopwrd1.append(word)


stopwords2 = stopwords.words('english')


stopwords3 = get_stop_words('english')

#from https://www.ranks.nl/stopwords
stopwords4 = ['a ', 'able', 'about', 'above', 'abst', 'accordance', 'according', 'accordingly', 'across', 'act', 'actually', 'added', 'adj', 'affected', 'affecting', 'affects', 'after', 'afterwards', 'again', 'against', 'ah', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'announce', 'another', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apparently', 'approximately', 'are', 'aren', 'arent', 'arise', 'around', 'as', 'aside', 'ask', 'asking', 'at', 'auth', 'available', 'away', 'awfully', 'b', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'begin', 'beginning', 'beginnings', 'begins', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'between', 'beyond', 'biol', 'both', 'brief', 'briefly', 'but', 'by', 'c', 'ca', 'came', 'can', 'cannot', "can't", 'cause', 'causes', 'certain', 'certainly', 'co', 'com', 'come', 'comes', 'contain', 'containing', 'contains', 'could', 'couldnt', 'd', 'date', 'did', "didn't", 'different', 'do', 'does', "doesn't", 'doing', 'done', "don't", 'down', 'downwards', 'due', 'during', 'e', 'each', 'ed', 'edu', 'effect', 'eg', 'eight', 'eighty', 'either', 'else', 'elsewhere', 'end', 'ending', 'enough', 'especially', 'et', 'et-al', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'ex', 'except', 'f', 'far', 'few', 'ff', 'fifth', 'first', 'five', 'fix', 'followed', 'following', 'follows', 'for', 'former', 'formerly', 'forth', 'found', 'four', 'from', 'further', 'furthermore', 'g', 'gave', 'get', 'gets', 'getting', 'give', 'given', 'gives', 'giving', 'go', 'goes', 'gone', 'got', 'gotten', 'h', 'had', 'happens', 'hardly', 'has', "hasn't", 'have', "haven't", 'having', 'he', 'hed', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'heres', 'hereupon', 'hers', 'herself', 'hes', 'hi', 'hid', 'him', 'himself', 'his', 'hither', 'home', 'how', 'howbeit', 'however', 'hundred', 'i', 'id', 'ie', 'if', "i'll", 'im', 'immediate', 'immediately', 'importance', 'important', 'in', 'inc', 'indeed', 'index', 'information', 'instead', 'into', 'invention', 'inward', 'is', "isn't", 'it', 'itd', "it'll", 'its', 'itself', "i've", 'j', 'just', 'k', 'keep\tkeeps', 'kept', 'kg', 'km', 'know', 'known', 'knows', 'l', 'largely', 'last', 'lately', 'later', 'latter', 'latterly', 'least', 'less', 'lest', 'let', 'lets', 'like', 'liked', 'likely', 'line', 'little', "'ll", 'look', 'looking', 'looks', 'ltd', 'm', 'made', 'mainly', 'make', 'makes', 'many', 'may', 'maybe', 'me', 'mean', 'means', 'meantime', 'meanwhile', 'merely', 'mg', 'might', 'million', 'miss', 'ml', 'more', 'moreover', 'most', 'mostly', 'mr', 'mrs', 'much', 'mug', 'must', 'my', 'myself', 'n', 'na', 'name', 'namely', 'nay', 'nd', 'near', 'nearly', 'necessarily', 'necessary', 'need', 'needs', 'neither', 'never', 'nevertheless', 'new', 'next', 'nine', 'ninety', 'no', 'nobody', 'non', 'none', 'nonetheless', 'noone', 'nor', 'normally', 'nos', 'not', 'noted', 'nothing', 'now', 'nowhere', 'o', 'obtain', 'obtained', 'obviously', 'of', 'off', 'often', 'oh', 'ok', 'okay', 'old', 'omitted', 'on', 'once', 'one', 'ones', 'only', 'onto', 'or', 'ord', 'other', 'others', 'otherwise', 'ought', 'our', 'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'owing', 'own', 'p', 'page', 'pages', 'part', 'particular', 'particularly', 'past', 'per', 'perhaps', 'placed', 'please', 'plus', 'poorly', 'possible', 'possibly', 'potentially', 'pp', 'predominantly', 'present', 'previously', 'primarily', 'probably', 'promptly', 'proud', 'provides', 'put', 'q', 'que', 'quickly', 'quite', 'qv', 'r', 'ran', 'rather', 'rd', 're', 'readily', 'really', 'recent', 'recently', 'ref', 'refs', 'regarding', 'regardless', 'regards', 'related', 'relatively', 'research', 'respectively', 'resulted', 'resulting', 'results', 'right', 'run', 's', 'said', 'same', 'saw', 'say', 'saying', 'says', 'sec', 'section', 'see', 'seeing', 'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves', 'sent', 'seven', 'several', 'shall', 'she', 'shed', "she'll", 'shes', 'should', "shouldn't", 'show', 'showed', 'shown', 'showns', 'shows', 'significant', 'significantly', 'similar', 'similarly', 'since', 'six', 'slightly', 'so', 'some', 'somebody', 'somehow', 'someone', 'somethan', 'something', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry', 'specifically', 'specified', 'specify', 'specifying', 'still', 'stop', 'strongly', 'sub', 'substantially', 'successfully', 'such', 'sufficiently', 'suggest', 'sup', 'sure\tt', 'take', 'taken', 'taking', 'tell', 'tends', 'th', 'than', 'thank', 'thanks', 'thanx', 'that', "that'll", 'thats', "that've", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 
             'thered', 'therefore', 'therein', "there'll", 'thereof', 'therere', 'theres', 'thereto', 'thereupon', "there've", 'these', 'they', 'theyd', "they'll", 'theyre', "they've", 'think', 'this', 'those', 'thou', 'though', 'though', 'thousand', 'throug', 'through', 'throughout', 'thru', 'thus', 'til', 'tip', 'to', 'together', 'too', 'took', 'toward', 'towards', 'tried', 'tries', 'truly', 'try', 'trying', 'ts', 'twice', 'two', 'u', 'un', 'under', 'unfortunately', 'unless', 'unlike', 'unlikely', 'until', 'unto', 'up', 'upon', 'ups', 'us', 'use', 'used', 'useful', 'usefully', 'usefulness', 'uses', 'using', 'usually', 'v', 'value', 'various', "'ve", 'very', 'via', 'viz', 'vol', 'vols', 'vs', 'w', 'want', 'wants', 'was', 'wasnt', 'way', 'we', 'wed', 'welcome', "we'll", 'went', 'were', 'werent', "we've", 'what', 'whatever', "what'll", 'whats', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby', 'wherein', 'wheres', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whim', 'whither', 'who', 'whod', 'whoever', 'whole', "who'll", 'whom', 'whomever', 'whos', 'whose', 'why', 'widely', 'willing', 'wish', 'with', 'within', 'without', 'wont', 'words', 'world', 'would', 'wouldnt', 'www', 'x', 'y', 'yes', 'yet', 'you', 'youd', "you'll", 'your', 'youre', 'yours', 'yourself', 'yourselves', "you've", 'z', 'zero']

        

stopwords_305 = stopwrd1
stopwords_747= list(set(stopwrd1 + stopwords2+ stopwords3 +stopwords4))
stopwords_710= stopwords_747[:710]
print(len(stopwords_305))
print(len(stopwords_710))
# Out:
# 305
# 710

# %% [markdown]
# ### Creating Dataframe with an instance being a sentence, each instance will have the following information:
#
#
# - All POS taggs if word is not a stopword for default stop words loaded with SpaCy and the additioanl passed one
# - POS taggs or stopwords for each stop word list
# - Lemmas for each word in stantance
# - Sentence Length
# - Label indicating author
# - Author name
# - Name of play
# - ID for each play

# %%
def create_dataframe(corpus, authors, stopwrds2):
    
    """
    Input: corpus with all texts, authors, and additional list with stopwords
    
    runtime: 14m 27s for 76 files 
    
    output: Pandas dataframe with one sentence is an instance, which has the following information:
            - All POS taggs if word is not a stopword for default stop words loaded with SpaCy and the additional passed one
            - POS taggs or stopwords for each stop word list
            - Lemmas for each word in stantance
            - Sentence Length 
            - Label indicating author
            - Author name 
            - Name of play
            - ID for each play    
    """
    nlp = spacy.load("en")
    data=[]   
    corpus_per_author = get_ordered_lists(authors, corpus)
    
    play_id = -1
    for idx, corpus in enumerate(corpus_per_author):
        author=authors[idx]
        label=idx

        for play in corpus:
            play_id += 1

            drama=play[3:]
            doc = nlp(open(play).read())
            for sent in doc.sents:
                sentlen= len(sent)
                POS_stwrd = " "
                sentence= " "
                lemmas= " "
                POSstopwrds2 = " "
                POS= " "
                POS2 = " "
                for word in sent:
                    sentence += str(word)
                    sentence += str(" ")
                    lemmas += str(word.lemma_)
                    lemmas += str(" ")

                    if word.is_stop:
                        POS_stwrd += str(word) 
                        POS_stwrd += str(" ") 
                        
                    else:
                        POS_stwrd  += str(word.pos_)
                        POS_stwrd  += str(" ")
                       
                    if str(word) in stopwrds2:
                        POSstopwrds2 += str(word) 
                        POSstopwrds2 += str(" ")
                    else:
                        POSstopwrds2  += str(word.pos_)
                        POSstopwrds2  += str(" ")
                        
                    if not word.is_stop:
                        POS += str(word.pos_)
                        POS += " "
                    if str(word) not in stopwrds2:
                        POS2 += str(word.pos_)
                        POS2 += " "
                        
                        
                    
                data.append((sentence, POS, POS2, POS_stwrd, POSstopwrds2,  lemmas, sentlen, label, author, drama,  play_id))
            
    df=pd.DataFrame(data,
                    columns=
                    ["Sentence", "POSnotstopwrds", "POSnotstopwrds2", "POSstopwrds", "POSstopwrds2", "Lemmas", "Sentencelen","Label", "Author", "Play", "Play_id" ] )
    return df




y_authors = ['E-Shakespeare', 'L-Shakespeare', 'Marlowe', 'Middleton','Jonson', 'Chapman']
df = create_dataframe(corpus, y_authors, stopwords_710)

#saving df in directory as excel file called "DataFrame"
df.to_excel("DataFrame_SVM.xlsx")

# %%
#read saved df
df=pd.read_excel('DataFrame_SVM.xlsx', index_col=0) 
df.head(100)
# Out:
#                                              Sentence  \
# 0    As I remember , Adam , it was upon this fashi...
# 1    My brother Jaques he keeps at school , and \n...
# 2    His horses \n are bred better ; for , besides...
# 3    Besides this nothing that he so \n plentifull...
# 4    This is it , Adam , that \n grieves me ; and ...
# 5         Yonder comes my master , your brother . \n
# 6    Go apart , Adam , and thou shalt hear how he ...
# 7                                        Now , sir !
# 8                            what make you here ? \n
# 9    Nothing : I am not taught to make any thing ....
# 10                      What mar you then , sir ? \n
# 11   Marry , sir , I am helping you to mar that wh...
# 12   Marry , sir , be better employed , and be nau...
# 13   Shall I keep your hogs and eat husks with the...
# 14   What prodigal portion have I spent , that I s...
# 15                Know you where your are , sir ? \n
# 16   O , sir , very well ; here in your orchard . \n
# 17                   Know you before whom , sir ? \n
# 18       Ay , better than him I am before knows me .
# 19   I know \n you are my eldest brother ; and , i...
# 20   The \n courtesy of nations allows you my bett...
# 21   I have as much of my father in me as \n you ;...
# 22                                   What , boy ! \n
# 23   Come , come , elder brother , you are too you...
# 24          Wilt thou lay hands on me , villain ? \n
# 25   I am no villain ; I am the youngest son of Si...
# 26                                         Wert thou
# 27   not my brother , I would not take this hand \...
# 28   Sweet masters , be patient : for your father ...
# 29                            Let me go , I say . \n
# ..                                                ...
# 70   And thou wert best look to't ; for if \n thou...
# 71   I speak but brotherly of him ; but \n should ...
# 72         I am heartily glad I came hither to you .
# 73   If he come \n to - morrow , I 'll give him hi...
# 74                      Farewell , good Charles . \n
# 75                   Now will I stir this gamester :
# 76   I hope I shall see \n an end of him ; for my ...
# 77   Yet he 's gentle , never \n schooled and yet ...
# 78   I pray thee , Rosalind , sweet my coz , be me...
# 79   Dear Celia , I show more mirth than I am mist...
# 80   Unless you could \n teach me to forget a bani...
# 81                                            Herein
# 82   I see thou lovest me not with the full weight...
# 83   If my uncle , thy banished father , \n had ba...
# 84   Well , I will forget the condition of my esta...
# 85                  You know my father hath no child
# 86             but I , nor none is \n like to have :
# 87   and , truly , when he dies , thou shalt \n be...
# 88   From henceforth I will , coz , and devise spo...
# 89   Let \n me see ; what think you of falling in ...
# 90   Marry , I prithee , do , to make sport withal...
# 91               What shall be our sport , then ? \n
# 92   Let us sit and mock the good housewife Fortun...
# 93   I would we could do so , for her benefits are...
# 94   ' Tis true ; for those that she makes fair sh...
# 95   Nay , now thou goest from Fortune 's office t...
# 96   Nature 's : Fortune reigns in gifts of the wo...
# 97                                              No ?
# 98   when Nature hath made a fair creature , may s...
# 99   Though Nature \n hath given us wit to flout a...
#
#                                        POSnotstopwrds  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT NOUN SPACE VE...
# 1    ADJ NOUN PROPN VERB NOUN PUNCT SPACE NOUN VER...
# 2    ADJ NOUN SPACE VERB ADV PUNCT PUNCT ADJ SPACE...
# 3    ADP SPACE ADV VERB PUNCT NOUN VERB SPACE NOUN...
# 4    DET PUNCT PROPN PUNCT SPACE VERB PUNCT NOUN N...
# 5             PROPN VERB NOUN PUNCT NOUN PUNCT SPACE
# 6    VERB ADV PUNCT PROPN PUNCT VERB NOUN VERB SPA...
# 7                               ADV PUNCT NOUN PUNCT
# 8                                        PUNCT SPACE
# 9              NOUN PUNCT PRON VERB NOUN PUNCT SPACE
# 10                  NOUN NOUN PUNCT NOUN PUNCT SPACE
# 11   PROPN PUNCT NOUN PUNCT PRON VERB VERB PROPN S...
# 12   PROPN PUNCT NOUN PUNCT ADV VERB PUNCT ADJ ADV...
# 13             PROPN PRON NOUN VERB NOUN PUNCT SPACE
# 14   NOUN ADJ NOUN PRON VERB PUNCT PRON SPACE VERB...
# 15                       VERB PUNCT NOUN PUNCT SPACE
# 16      NOUN PUNCT NOUN PUNCT PUNCT NOUN PUNCT SPACE
# 17                       VERB PUNCT NOUN PUNCT SPACE
# 18                    INTJ PUNCT ADJ PRON VERB PUNCT
# 19   PRON VERB SPACE ADJ NOUN PUNCT PUNCT ADJ SPAC...
# 20   DET SPACE NOUN NOUN VERB ADJ PUNCT SPACE PUNC...
# 21   PRON NOUN SPACE PUNCT ADV PUNCT PRON VERB PUN...
# 22                       NOUN PUNCT INTJ PUNCT SPACE
# 23   VERB PUNCT VERB PUNCT ADJ NOUN PUNCT ADJ PUNC...
# 24       PROPN VERB VERB NOUN PUNCT NOUN PUNCT SPACE
# 25   PRON NOUN PUNCT PRON ADJ NOUN PROPN SPACE PRO...
# 26                                        PROPN VERB
# 27   NOUN PUNCT PRON NOUN SPACE ADJ NOUN ADP VERB ...
# 28   ADJ NOUN PUNCT ADJ PUNCT NOUN PART SPACE NOUN...
# 29                       VERB PUNCT PRON PUNCT SPACE
# ..                                                ...
# 70   CCONJ VERB NOUN ADV VERB ADJ PUNCT SPACE VERB...
# 71   PRON VERB ADV PUNCT SPACE PRON VERB PRON PUNC...
# 72                 PRON ADV ADJ PRON VERB NOUN PUNCT
# 73   ADP VERB SPACE PUNCT NOUN PUNCT PRON VERB NOU...
# 74                 PROPN PUNCT ADJ PROPN PUNCT SPACE
# 75                          ADV PRON VERB NOUN PUNCT
# 76   PRON VERB PRON VERB SPACE NOUN PUNCT NOUN PUN...
# 77   ADV VERB ADJ PUNCT SPACE VERB VERB PUNCT ADJ ...
# 78   PRON VERB PRON PUNCT PROPN PUNCT ADJ NOUN PUN...
# 79   PROPN PROPN PUNCT PRON NOUN PRON NOUN PUNCT S...
# 80   ADP SPACE VERB VERB VERB NOUN PUNCT SPACE VER...
# 81                                             PROPN
# 82     PRON VERB ADJ NOUN SPACE PRON VERB PRON PUNCT
# 83   ADP NOUN PUNCT ADJ VERB NOUN PUNCT SPACE VERB...
# 84   INTJ PUNCT PRON VERB NOUN NOUN PUNCT SPACE NO...
# 85                          PRON VERB NOUN NOUN NOUN
# 86                        PRON PUNCT SPACE ADJ PUNCT
# 87   PUNCT ADV PUNCT VERB PUNCT VERB NOUN SPACE NO...
# 88      ADP ADV PRON PUNCT ADV PUNCT VERB NOUN PUNCT
# 89       VERB SPACE PUNCT VERB VERB NOUN PUNCT SPACE
# 90   PROPN PUNCT PRON VERB PUNCT PUNCT NOUN ADJ PU...
# 91                  NOUN VERB NOUN PUNCT PUNCT SPACE
# 92   VERB VERB VERB ADJ NOUN PROPN SPACE NOUN PUNC...
# 93   PRON PUNCT NOUN SPACE ADV VERB PUNCT ADJ ADJ ...
# 94   PUNCT PROPN ADJ PUNCT VERB ADJ ADJ SPACE VERB...
# 95       PROPN PUNCT VERB NOUN PROPN PART NOUN SPACE
# 96   PROPN PART PUNCT NOUN NOUN NOUN NOUN PUNCT SP...
# 97                                        INTJ PUNCT
# 98   PROPN NOUN ADJ NOUN PUNCT SPACE PROPN VERB NO...
# 99   ADP PROPN SPACE NOUN VERB NOUN VERB PROPN PUN...
#
#                                       POSnotstopwrds2  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT DET NOUN SPAC...
# 1    ADJ NOUN PROPN VERB NOUN PUNCT SPACE NOUN VER...
# 2    ADJ NOUN SPACE VERB ADV PUNCT PUNCT ADJ SPACE...
# 3    ADP DET SPACE ADV PUNCT NOUN NOUN SPACE ADJ N...
# 4    DET PUNCT PROPN PUNCT SPACE VERB PUNCT NOUN N...
# 5                  PROPN NOUN PUNCT NOUN PUNCT SPACE
# 6    VERB ADV PUNCT PROPN PUNCT NOUN VERB SPACE VE...
# 7                               ADV PUNCT NOUN PUNCT
# 8                                        PUNCT SPACE
# 9              NOUN PUNCT PRON VERB NOUN PUNCT SPACE
# 10                  NOUN NOUN PUNCT NOUN PUNCT SPACE
# 11   PROPN PUNCT NOUN PUNCT PRON VERB VERB PROPN S...
# 12   PROPN PUNCT NOUN PUNCT ADV VERB PUNCT ADJ ADV...
# 13             PROPN PRON NOUN VERB NOUN PUNCT SPACE
# 14   NOUN ADJ NOUN PRON VERB PUNCT PRON SPACE NOUN...
# 15                       VERB PUNCT NOUN PUNCT SPACE
# 16      NOUN PUNCT NOUN PUNCT PUNCT NOUN PUNCT SPACE
# 17                       VERB PUNCT NOUN PUNCT SPACE
# 18                         INTJ PUNCT ADJ PRON PUNCT
# 19   PRON SPACE ADJ NOUN PUNCT PUNCT ADJ SPACE NOU...
# 20   DET SPACE NOUN NOUN VERB ADJ PUNCT SPACE PUNC...
# 21   PRON ADJ NOUN SPACE PUNCT ADV PUNCT PRON VERB...
# 22                       NOUN PUNCT INTJ PUNCT SPACE
# 23   VERB PUNCT PUNCT ADJ NOUN PUNCT ADJ DET PUNCT...
# 24            PROPN VERB NOUN PUNCT NOUN PUNCT SPACE
# 25   PRON NOUN PUNCT PRON ADJ NOUN PROPN SPACE PRO...
# 26                                             PROPN
# 27   NOUN PUNCT PRON DET NOUN SPACE ADJ NOUN ADP D...
# 28   ADJ NOUN PUNCT ADJ PUNCT NOUN PART SPACE NOUN...
# 29                       VERB PUNCT PRON PUNCT SPACE
# ..                                                ...
# 70   CCONJ NOUN ADV ADJ PUNCT SPACE ADJ ADJ NOUN S...
# 71   PRON VERB ADV PUNCT SPACE PRON VERB PRON PUNC...
# 72                           PRON ADV ADJ PRON PUNCT
# 73   ADP SPACE PUNCT NOUN PUNCT PRON ADJ NOUN PUNC...
# 74                 PROPN PUNCT ADJ PROPN PUNCT SPACE
# 75                      ADV PRON VERB DET NOUN PUNCT
# 76   PRON VERB PRON SPACE PUNCT NOUN PUNCT PRON PU...
# 77   ADV VERB ADJ PUNCT SPACE VERB VERB PUNCT ADJ ...
# 78   PRON VERB PRON PUNCT PROPN PUNCT ADJ NOUN PUN...
# 79   PROPN PROPN PUNCT PRON VERB NOUN PRON NOUN PU...
# 80   ADP SPACE VERB VERB VERB NOUN PUNCT SPACE VER...
# 81                                             PROPN
# 82          PRON ADJ NOUN SPACE PRON VERB PRON PUNCT
# 83   ADP NOUN PUNCT ADJ VERB NOUN PUNCT SPACE VERB...
# 84   INTJ PUNCT PRON VERB NOUN NOUN PUNCT SPACE NO...
# 85                               PRON NOUN NOUN NOUN
# 86                            PRON PUNCT SPACE PUNCT
# 87   PUNCT PUNCT VERB PUNCT NOUN SPACE ADJ NOUN PU...
# 88      ADP ADV PRON PUNCT ADV PUNCT VERB NOUN PUNCT
# 89            VERB SPACE PUNCT VERB NOUN PUNCT SPACE
# 90   PROPN PUNCT PRON VERB PUNCT PUNCT NOUN ADJ PU...
# 91                       NOUN NOUN PUNCT PUNCT SPACE
# 92   VERB VERB VERB ADJ NOUN PROPN SPACE NOUN PUNC...
# 93   PRON PUNCT NOUN SPACE ADV VERB PUNCT ADJ ADJ ...
# 94   PUNCT PROPN ADJ PUNCT ADJ ADJ SPACE ADJ PUNCT...
# 95            PROPN PUNCT NOUN PROPN PART NOUN SPACE
# 96   PROPN PART PUNCT NOUN NOUN NOUN PUNCT SPACE N...
# 97                                        INTJ PUNCT
# 98   PROPN NOUN ADJ NOUN PUNCT SPACE PROPN VERB NO...
# 99   ADP PROPN SPACE NOUN NOUN VERB PROPN PUNCT NO...
#
#                                           POSstopwrds  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it was upon t...
# 1    ADJ NOUN PROPN he VERB at NOUN PUNCT and SPAC...
# 2    ADJ NOUN SPACE are VERB ADV PUNCT for PUNCT b...
# 3    ADP this nothing that he so SPACE ADV VERB me...
# 4    DET is it PUNCT PROPN PUNCT that SPACE VERB m...
# 5     PROPN VERB my NOUN PUNCT your NOUN PUNCT SPACE
# 6    VERB ADV PUNCT PROPN PUNCT and VERB NOUN VERB...
# 7                               ADV PUNCT NOUN PUNCT
# 8                     what make you here PUNCT SPACE
# 9    NOUN PUNCT PRON am not VERB to make any NOUN ...
# 10         NOUN NOUN you then PUNCT NOUN PUNCT SPACE
# 11   PROPN PUNCT NOUN PUNCT PRON am VERB you to VE...
# 12   PROPN PUNCT NOUN PUNCT be ADV VERB PUNCT and ...
# 13   PROPN PRON keep your NOUN and VERB NOUN with ...
# 14   NOUN ADJ NOUN have PRON VERB PUNCT that PRON ...
# 15    VERB you where your are PUNCT NOUN PUNCT SPACE
# 16   NOUN PUNCT NOUN PUNCT very well PUNCT here in...
# 17       VERB you before whom PUNCT NOUN PUNCT SPACE
# 18   INTJ PUNCT ADJ than him PRON am before VERB m...
# 19   PRON VERB SPACE you are my ADJ NOUN PUNCT and...
# 20   DET SPACE NOUN of NOUN VERB you my ADJ PUNCT ...
# 21   PRON have as much of my NOUN in me as SPACE y...
# 22                       NOUN PUNCT INTJ PUNCT SPACE
# 23   VERB PUNCT VERB PUNCT ADJ NOUN PUNCT you are ...
# 24   PROPN VERB VERB NOUN on me PUNCT NOUN PUNCT S...
# 25   PRON am no NOUN PUNCT PRON am the ADJ NOUN of...
# 26                                        PROPN VERB
# 27   not my NOUN PUNCT PRON would not take this NO...
# 28   ADJ NOUN PUNCT be ADJ PUNCT for your NOUN PAR...
# 29             VERB me go PUNCT PRON say PUNCT SPACE
# ..                                                ...
# 70   CCONJ VERB NOUN ADV VERB ADJ PUNCT for if SPA...
# 71   PRON VERB but ADV of him PUNCT but SPACE shou...
# 72       PRON am ADV ADJ PRON VERB NOUN to you PUNCT
# 73   ADP he VERB SPACE to PUNCT NOUN PUNCT PRON VE...
# 74                 PROPN PUNCT ADJ PROPN PUNCT SPACE
# 75                ADV will PRON VERB this NOUN PUNCT
# 76   PRON VERB PRON VERB see SPACE an NOUN of him ...
# 77   ADV he VERB ADJ PUNCT never SPACE VERB and ye...
# 78   PRON VERB PRON PUNCT PROPN PUNCT ADJ my NOUN ...
# 79   PROPN PROPN PUNCT PRON show more NOUN than PR...
# 80   ADP you could SPACE VERB me to VERB a VERB NO...
# 81                                             PROPN
# 82   PRON see VERB ADJ me not with the full NOUN S...
# 83   ADP my NOUN PUNCT ADJ VERB NOUN PUNCT SPACE h...
# 84   INTJ PUNCT PRON will VERB the NOUN of my NOUN...
# 85                    PRON VERB my NOUN NOUN no NOUN
# 86   but PRON PUNCT nor none is SPACE ADJ to have ...
# 87   and PUNCT ADV PUNCT when he VERB PUNCT VERB N...
# 88   ADP ADV PRON will PUNCT ADV PUNCT and VERB NO...
# 89   VERB SPACE me see PUNCT what VERB you of VERB...
# 90   PROPN PUNCT PRON VERB PUNCT do PUNCT to make ...
# 91      NOUN VERB be our NOUN PUNCT then PUNCT SPACE
# 92   VERB us VERB and VERB the ADJ NOUN PROPN from...
# 93   PRON would we could do so PUNCT for her NOUN ...
# 94   PUNCT PROPN ADJ PUNCT for those that she VERB...
# 95   PROPN PUNCT now VERB NOUN from PROPN PART NOU...
# 96   PROPN PART PUNCT NOUN NOUN in NOUN of the NOU...
# 97                                        INTJ PUNCT
# 98   when PROPN NOUN made a ADJ NOUN PUNCT may she...
# 99   ADP PROPN SPACE NOUN VERB us NOUN to VERB at ...
#
#                                          POSstopwrds2  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it was upon D...
# 1    ADJ NOUN PROPN he VERB at NOUN PUNCT and SPAC...
# 2    ADJ NOUN SPACE are VERB ADV PUNCT for PUNCT b...
# 3    ADP DET nothing that he so SPACE ADV gives me...
# 4    DET is it PUNCT PROPN PUNCT that SPACE VERB m...
# 5    PROPN comes my NOUN PUNCT your NOUN PUNCT SPACE
# 6    VERB ADV PUNCT PROPN PUNCT and thou NOUN VERB...
# 7                               ADV PUNCT NOUN PUNCT
# 8                     what make you here PUNCT SPACE
# 9    NOUN PUNCT PRON am not VERB to make any NOUN ...
# 10         NOUN NOUN you then PUNCT NOUN PUNCT SPACE
# 11   PROPN PUNCT NOUN PUNCT PRON am VERB you to VE...
# 12   PROPN PUNCT NOUN PUNCT be ADV VERB PUNCT and ...
# 13   PROPN PRON keep your NOUN and VERB NOUN with ...
# 14   NOUN ADJ NOUN have PRON VERB PUNCT that PRON ...
# 15    VERB you where your are PUNCT NOUN PUNCT SPACE
# 16   NOUN PUNCT NOUN PUNCT very well PUNCT here in...
# 17       VERB you before whom PUNCT NOUN PUNCT SPACE
# 18   INTJ PUNCT ADJ than him PRON am before knows ...
# 19   PRON know SPACE you are my ADJ NOUN PUNCT and...
# 20   DET SPACE NOUN of NOUN VERB you my ADJ PUNCT ...
# 21   PRON have as ADJ of my NOUN in me as SPACE yo...
# 22                       NOUN PUNCT INTJ PUNCT SPACE
# 23   VERB PUNCT come PUNCT ADJ NOUN PUNCT you are ...
# 24   PROPN thou VERB NOUN on me PUNCT NOUN PUNCT S...
# 25   PRON am no NOUN PUNCT PRON am the ADJ NOUN of...
# 26                                        PROPN thou
# 27   not my NOUN PUNCT PRON would not take DET NOU...
# 28   ADJ NOUN PUNCT be ADJ PUNCT for your NOUN PAR...
# 29             VERB me go PUNCT PRON say PUNCT SPACE
# ..                                                ...
# 70   CCONJ thou NOUN ADV look ADJ PUNCT for if SPA...
# 71   PRON VERB but ADV of him PUNCT but SPACE shou...
# 72     PRON am ADV ADJ PRON came hither to you PUNCT
# 73   ADP he come SPACE to PUNCT NOUN PUNCT PRON 'l...
# 74                 PROPN PUNCT ADJ PROPN PUNCT SPACE
# 75                 ADV will PRON VERB DET NOUN PUNCT
# 76   PRON VERB PRON shall see SPACE an end of him ...
# 77   ADV he VERB ADJ PUNCT never SPACE VERB and ye...
# 78   PRON VERB PRON PUNCT PROPN PUNCT ADJ my NOUN ...
# 79   PROPN PROPN PUNCT PRON VERB more NOUN than PR...
# 80   ADP you could SPACE VERB me to VERB a VERB NO...
# 81                                             PROPN
# 82   PRON see thou ADJ me not with the full NOUN S...
# 83   ADP my NOUN PUNCT ADJ VERB NOUN PUNCT SPACE h...
# 84   INTJ PUNCT PRON will VERB the NOUN of my NOUN...
# 85                    PRON know my NOUN NOUN no NOUN
# 86   but PRON PUNCT nor none is SPACE like to have...
# 87   and PUNCT truly PUNCT when he VERB PUNCT thou...
# 88   ADP ADV PRON will PUNCT ADV PUNCT and VERB NO...
# 89   VERB SPACE me see PUNCT what think you of VER...
# 90   PROPN PUNCT PRON VERB PUNCT do PUNCT to make ...
# 91     NOUN shall be our NOUN PUNCT then PUNCT SPACE
# 92   VERB us VERB and VERB the ADJ NOUN PROPN from...
# 93   PRON would we could do so PUNCT for her NOUN ...
# 94   PUNCT PROPN ADJ PUNCT for those that she make...
# 95   PROPN PUNCT now thou NOUN from PROPN PART NOU...
# 96   PROPN PART PUNCT NOUN NOUN in NOUN of the wor...
# 97                                        INTJ PUNCT
# 98   when PROPN NOUN made a ADJ NOUN PUNCT may she...
# 99   ADP PROPN SPACE NOUN given us NOUN to VERB at...
#
#                                                Lemmas  Sentencelen  Label  \
# 0    as -PRON- remember , adam , -PRON- be upon th...           50      0
# 1    -PRON- brother jaques -PRON- keep at school ,...           68      0
# 2    -PRON- horse \n be breed better ; for , besid...           66      0
# 3    besides this nothing that -PRON- so \n plenti...           61      0
# 4    this be -PRON- , adam , that \n grieve -PRON-...           55      0
# 5    yonder come -PRON- master , -PRON- brother . \n             9      0
# 6    go apart , adam , and thou shalt hear how -PR...           18      0
# 7                                        now , sir !             4      0
# 8                         what make -PRON- here ? \n             6      0
# 9    nothing : -PRON- be not teach to make any thi...           12      0
# 10                   what mar -PRON- then , sir ? \n             8      0
# 11   marry , sir , -PRON- be help -PRON- to mar th...           27      0
# 12   marry , sir , be better employ , and be naugh...           14      0
# 13   shall -PRON- keep -PRON- hog and eat husk wit...           12      0
# 14   what prodigal portion have -PRON- spend , tha...           17      0
# 15            know -PRON- where -PRON- be , sir ? \n             9      0
# 16   o , sir , very well ; here in -PRON- orchard ...           13      0
# 17                know -PRON- before whom , sir ? \n             8      0
# 18   ay , good than -PRON- -PRON- be before know -...           11      0
# 19   -PRON- know \n -PRON- be -PRON- eld brother ;...           25      0
# 20   the \n courtesy of nation allow -PRON- -PRON-...           39      0
# 21   -PRON- have as much of -PRON- father in -PRON...           30      0
# 22                                   what , boy ! \n             5      0
# 23   come , come , elder brother , -PRON- be too y...           15      0
# 24       wilt thou lie hand on -PRON- , villain ? \n            10      0
# 25   -PRON- be no villain ; -PRON- be the young so...           38      0
# 26                                         wert thou             2      0
# 27   not -PRON- brother , -PRON- would not take th...           34      0
# 28   sweet master , be patient : for -PRON- father...           18      0
# 29                   let -PRON- go , -PRON- say . \n             8      0
# ..                                                ...          ...    ...
# 70   and thou wert best look to't ; for if \n thou...           92      0
# 71   -PRON- speak but brotherly of -PRON- ; but \n...           34      0
# 72   -PRON- be heartily glad -PRON- come hither to...           10      0
# 73   if -PRON- come \n to - morrow , -PRON- will g...           40      0
# 74                      farewell , good charles . \n             6      0
# 75              now will -PRON- stir this gamester :             7      0
# 76   -PRON- hope -PRON- shall see \n an end of -PR...           28      0
# 77   yet -PRON- be gentle , never \n school and ye...           90      0
# 78   -PRON- pray thee , rosalind , sweet -PRON- co...           14      0
# 79   dear celia , -PRON- show more mirth than -PRO...           22      0
# 80   unless -PRON- could \n teach -PRON- to forget...           26      0
# 81                                            herein             1      0
# 82   -PRON- see thou lov -PRON- not with the full ...           16      0
# 83   if -PRON- uncle , thy banish father , \n have...           67      0
# 84   well , -PRON- will forget the condition of -P...           18      0
# 85           -PRON- know -PRON- father hath no child             7      0
# 86        but -PRON- , nor none be \n like to have :            11      0
# 87   and , truly , when -PRON- die , thou shalt \n...           71      0
# 88   from henceforth -PRON- will , coz , and devis...           11      0
# 89   let \n -PRON- see ; what think -PRON- of fall...           14      0
# 90   marry , -PRON- prithee , do , to make sport w...           45      0
# 91            what shall be -PRON- sport , then ? \n             9      0
# 92   let -PRON- sit and mock the good housewife fo...           24      0
# 93   -PRON- would -PRON- could do so , for -PRON- ...           31      0
# 94   ' tis true ; for those that -PRON- make fair ...           31      0
# 95   nay , now thou goest from fortune 's office t...           11      0
# 96   nature 's : fortune reign in gift of the worl...           20      0
# 97                                              no ?             2      0
# 98   when nature hath make a fair creature , may -...           19      0
# 99   though nature \n hath give -PRON- wit to flou...           27      0
#
#            Author                               Play  Play_id
# 0   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 1   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 2   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 3   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 4   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 5   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 6   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 7   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 8   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 9   E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 10  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 11  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 12  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 13  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 14  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 15  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 16  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 17  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 18  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 19  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 20  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 21  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 22  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 23  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 24  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 25  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 26  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 27  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 28  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 29  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# ..            ...                                ...      ...
# 70  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 71  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 72  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 73  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 74  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 75  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 76  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 77  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 78  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 79  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 80  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 81  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 82  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 83  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 84  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 85  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 86  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 87  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 88  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 89  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 90  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 91  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 92  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 93  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 94  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 95  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 96  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 97  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 98  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
# 99  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Implementing the same features as done by Fox et al. (2014)
# ### using each sentence as instance

# %%
#split the dataframe into train and test data
train_data, test_data= train_test_split(df, test_size=0.33)

# %% [markdown]
# Exploring which size of stop word sets has the better outcome.

# %% [markdown]
# #### 1. Using set of stop words of size 710 (as done by Fox et al.)

# %%
X_train_sent = train_data["Sentence"]
X_train_POS_710 = train_data["POSnotstopwrds2"]
X_train_POSstp_710 = train_data["POSstopwrds2"]

y_train= train_data["Label"]

#do the same thing for test data
X_test_sent = test_data["Sentence"]
X_test_POS_710 = test_data["POSnotstopwrds2"]
X_test_POSstp_710 = test_data["POSstopwrds2"]

y_test= test_data["Label"]

# %%
cvec1 = CountVectorizer(vocabulary= stopwords_710, max_features=1000) 
cvec2 = CountVectorizer(max_features=1000)
cvec3 = CountVectorizer(ngram_range=(2,2), max_features=1000)


training_features_710 = np.hstack((
    cvec1.fit_transform(X_train_sent).toarray(),
    cvec2.fit_transform(X_train_POS_710).toarray(),
    cvec3.fit_transform(X_train_POSstp_710).toarray(),
    ))


test_features_710 = np.hstack((
        cvec1.transform(X_test_sent).toarray(),
        cvec2.transform(X_test_POS_710).toarray(),
        cvec3.transform(X_test_POSstp_710).toarray(),
    ))


# cvec1.vocabulary_
# cvec2.vocabulary_
# cvec3.vocabulary_

# %%
svm = LinearSVC()
svm.fit(training_features_710,y_train )
pred_svm=svm.score(test_features_710, y_test)

nb = MultinomialNB(alpha=0.1)
nb.fit(training_features_710,y_train, y_train )
pred_MB=nb.score(test_features_710, y_test)
# Out:
# C:\Users\ninah\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\naive_bayes.py:461: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = (np.log(self.class_count_) -

# %%
print("Prediction of Naive Bayes has score of " + str(pred_MB))
print("Prediction of multi SVM has score of " + str(pred_svm))
# Out:
# Prediction of Naive Bayes has score of 0.3483574461069206
# Prediction of multi SVM has score of 0.4697662915790775

# %% [markdown]
# #### 2. Using smaller set of stopwords (305)

# %%
X_train_sent = train_data["Sentence"]
X_train_POS_305 = train_data["POSnotstopwrds"]
X_train_POSstp_305 = train_data["POSstopwrds"]

y_train= train_data["Label"]

#do the same thing for test data
X_test_sent= test_data["Sentence"]
X_test_POS_305= test_data["POSnotstopwrds"]
X_test_POSstp_305 = test_data["POSstopwrds"]

y_test= test_data["Label"]

# %%
#then define what columns I want

cvec1 = CountVectorizer(vocabulary= stopwords_305, max_features=1000) 
cvec2 = CountVectorizer(max_features=1000)
cvec3 = CountVectorizer(ngram_range=(2,2), max_features=1000)


training_features_305 = np.hstack((
    cvec1.fit_transform(X_train_sent).toarray(),
    cvec2.fit_transform(X_train_POS_305).toarray(),
    cvec3.fit_transform(X_train_POSstp_305).toarray(),
    ))


test_features_305 = np.hstack((
        cvec1.transform(X_test_sent).toarray(),
        cvec2.transform(X_test_POS_305).toarray(),
        cvec3.transform(X_test_POS_305).toarray(),
    ))
# cvec1.vocabulary_
# cvec2.vocabulary_
# cvec3.vocabulary_

# %%
svm = LinearSVC()
svm.fit(training_features_305, y_train)
pred_305_svm= svm.score(test_features_305, y_test)

nb = MultinomialNB(alpha=0.1)
nb.fit(training_features_305, y_train)
pred_305_nb= nb.score(test_features_305, y_test)

# %%
print("Prediction of Naive Bayes has score of " + str(pred_305_nb))
print("Prediction of multi SVM has score of " + str(pred_305_svm))
# Out:
# Prediction of Naive Bayes has score of 0.3977577181484687
# Prediction of multi SVM has score of 0.41972713408350854

# %% [markdown]
# __Results__
#
# Overall, the results are low, nevertheless, the multi SVM  performs better across all set of stop words.
# Moreover, the list with 710 stop words delivered a higher score.
#
#
# |     Stops  | NB    | SVM  |
# |--------|--------|--------|
# | 305  | 0.3973 | 0.4105 |
# | 710 | 0.3439 | 0.4590 |
#
#
# Thus, in the following I will use the bigger list of stop words with a multiclass SVM classifier.

# %% [markdown]
# ## Predictions for each plays
#
# To get the prediction for each play, I will firstly use a 3-fold cross validation to get the prediction for each sentence.
# Following this I will look at each sentence of a play and take the majority class to get the final prediction of the author.

# %%
X_sent = df["Sentence"]
X_POS_710 = df["POSnotstopwrds2"] #do this with the bigger stop words set
X_POSstp_710= df["POSstopwrds2"]
y = df["Label"]

cvec1 = CountVectorizer(vocabulary= stopwrd1, max_features=1000, strip_accents="ascii") 
cvec2 = CountVectorizer(max_features=1000)
cvec3 = CountVectorizer(ngram_range=(2,2), max_features=1000)


X = np.hstack((
    cvec1.fit_transform(X_sent).toarray(),
    cvec2.fit_transform(X_POS_710).toarray(),
    cvec3.fit_transform(X_POSstp_710).toarray(),
    ))

clf = LinearSVC()
y_pred = cross_val_predict(clf, X, y, cv=3)

# %%
print(y_pred)
# Out:
# [0 0 0 ... 0 0 5]

# %%
df["Pred"] = y_pred
df.head()
df.to_excel("DataFrame_SVM_Preds.xlsx")

# %%
df.head()
# Out:
#                                             Sentence  \
# 0   As I remember , Adam , it was upon this fashi...
# 1   My brother Jaques he keeps at school , and \n...
# 2   His horses \n are bred better ; for , besides...
# 3   Besides this nothing that he so \n plentifull...
# 4   This is it , Adam , that \n grieves me ; and ...
#
#                                       POSnotstopwrds  \
# 0   ADP PRON VERB PUNCT PROPN PUNCT NOUN SPACE VE...
# 1   ADJ NOUN PROPN VERB NOUN PUNCT SPACE NOUN VER...
# 2   ADJ NOUN SPACE VERB ADV PUNCT PUNCT ADJ SPACE...
# 3   ADP SPACE ADV VERB PUNCT NOUN VERB SPACE NOUN...
# 4   DET PUNCT PROPN PUNCT SPACE VERB PUNCT NOUN N...
#
#                                      POSnotstopwrds2  \
# 0   ADP PRON VERB PUNCT PROPN PUNCT DET NOUN SPAC...
# 1   ADJ NOUN PROPN VERB NOUN PUNCT SPACE NOUN VER...
# 2   ADJ NOUN SPACE VERB ADV PUNCT PUNCT ADJ SPACE...
# 3   ADP DET SPACE ADV PUNCT NOUN NOUN SPACE ADJ N...
# 4   DET PUNCT PROPN PUNCT SPACE VERB PUNCT NOUN N...
#
#                                          POSstopwrds  \
# 0   ADP PRON VERB PUNCT PROPN PUNCT it was upon t...
# 1   ADJ NOUN PROPN he VERB at NOUN PUNCT and SPAC...
# 2   ADJ NOUN SPACE are VERB ADV PUNCT for PUNCT b...
# 3   ADP this nothing that he so SPACE ADV VERB me...
# 4   DET is it PUNCT PROPN PUNCT that SPACE VERB m...
#
#                                         POSstopwrds2  \
# 0   ADP PRON VERB PUNCT PROPN PUNCT it was upon D...
# 1   ADJ NOUN PROPN he VERB at NOUN PUNCT and SPAC...
# 2   ADJ NOUN SPACE are VERB ADV PUNCT for PUNCT b...
# 3   ADP DET nothing that he so SPACE ADV gives me...
# 4   DET is it PUNCT PROPN PUNCT that SPACE VERB m...
#
#                                               Lemmas  Sentencelen  Label  \
# 0   as -PRON- remember , adam , -PRON- be upon th...           50      0
# 1   -PRON- brother jaques -PRON- keep at school ,...           68      0
# 2   -PRON- horse \n be breed better ; for , besid...           66      0
# 3   besides this nothing that -PRON- so \n plenti...           61      0
# 4   this be -PRON- , adam , that \n grieve -PRON-...           55      0
#
#           Author                               Play  Play_id  Pred
# 0  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0     0
# 1  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0     0
# 2  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0     0
# 3  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0     1
# 4  E-Shakespeare  asyoulikeit.txt.E-Shakespeare.tok        0     4

# %%
corpus_per_author, y = get_lists(corpus, y_authors)

majority_class= {}
for idx, play in enumerate(corpus_per_author):
    mjc= mode(list(df.loc[lambda df: df['Play_id'] == idx]["Pred"]))[0]
    majority_class[play]=mjc
    
    
get_data= []

for idx, play in enumerate(corpus_per_author):
    canonical= y[idx]
    pred= int(majority_class[play])
    get_data.append((play, canonical, pred))
    
dfpred= pd.DataFrame(get_data, columns=["play", "canonical author", "predicted author"])  
# dfpred.head(77)
dfpred["acc"] =dfpred["canonical author"]==dfpred[ "predicted author"]
print(dfpred.loc[dfpred.acc == True, 'acc'].count()/len(corpus_per_author))
# Out:
# 0.5324675324675324

# %% [markdown]
# __Results__
#
# The accuary for the 3-fold-cross validation are rather low. It is very  likely that this is due to the imbalanced data set.
# Thus, we will procede the data such that one play is one instance with a Naive Bayes Classifier.
