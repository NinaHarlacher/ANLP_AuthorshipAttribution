# %% [markdown]
# ##  SVM Feature Engineering
#
# Uses
# - Support Vector Machine as classifier
# - provided original dataframe (DataFrame.xlsx), improved data frame (DataFrame_imp.xlsx)
# - basic features POS tag frequency, stop word frequency (of 507 and 305 stop words), n-grams of POS and stop words
#
# to test different additional features, namely
# - word frequency
# - keyword extraction
# - stemming
# - line length
# - sentence length
# - lemmatizing

# %%
#NOTE

#Results can differ depending on how the CountVectorizers in the get_feature functions are built. Two versions 
#have been tried and been found to affect the results for better or for worse in a non consistent way 
#in each feature.

#Version 1
#cvec1 = CountVectorizer(vocabulary = stopwords_507, strip_accents="ascii")#word freq of stop words
#cvec2 = CountVectorizer() #freq of POS tags
#cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii") #ngrams of POS/stops

#Version 2
#cvec1 = CountVectorizer(vocabulary= stopwords_507, strip_accents="ascii")#word freq of stop words
#cvec2 = CountVectorizer(max_features=1000, strip_accents="ascii") #freq of POS tags
#cvec3 = CountVectorizer(ngram_range=(2,2),max_features=1000, strip_accents="ascii") #ngrams of POS/stops

# %%
import os
import re
import spacy
import pandas as pd
from glob import glob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split
from sklearn import linear_model

import nltk
from nltk.corpus import stopwords
from stop_words import get_stop_words

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# ### Get Stop Words

# %%
nlp = spacy.load("en")
stopwrd1= []
for word in nlp.Defaults.stop_words:
    stopwrd1.append(word)


stopwords2 = stopwords.words('english')


stopwords3 = get_stop_words('english')

#from https://www.ranks.nl/stopwords
stopwords4 = ['a ', 'able', 'about', 'above', 'abst', 'accordance', 'according', 'accordingly', 'across', 'act', 'actually', 'added', 'adj', 'affected', 'affecting', 'affects', 'after', 'afterwards', 'again', 'against', 'ah', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'announce', 'another', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apparently', 'approximately', 'are', 'aren', 'arent', 'arise', 'around', 'as', 'aside', 'ask', 'asking', 'at', 'auth', 'available', 'away', 'awfully', 'b', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'begin', 'beginning', 'beginnings', 'begins', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'between', 'beyond', 'biol', 'both', 'brief', 'briefly', 'but', 'by', 'c', 'ca', 'came', 'can', 'cannot', "can't", 'cause', 'causes', 'certain', 'certainly', 'co', 'com', 'come', 'comes', 'contain', 'containing', 'contains', 'could', 'couldnt', 'd', 'date', 'did', "didn't", 'different', 'do', 'does', "doesn't", 'doing', 'done', "don't", 'down', 'downwards', 'due', 'during', 'e', 'each', 'ed', 'edu', 'effect', 'eg', 'eight', 'eighty', 'either', 'else', 'elsewhere', 'end', 'ending', 'enough', 'especially', 'et', 'et-al', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'ex', 'except', 'f', 'far', 'few', 'ff', 'fifth', 'first', 'five', 'fix', 'followed', 'following', 'follows', 'for', 'former', 'formerly', 'forth', 'found', 'four', 'from', 'further', 'furthermore', 'g', 'gave', 'get', 'gets', 'getting', 'give', 'given', 'gives', 'giving', 'go', 'goes', 'gone', 'got', 'gotten', 'h', 'had', 'happens', 'hardly', 'has', "hasn't", 'have', "haven't", 'having', 'he', 'hed', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'heres', 'hereupon', 'hers', 'herself', 'hes', 'hi', 'hid', 'him', 'himself', 'his', 'hither', 'home', 'how', 'howbeit', 'however', 'hundred', 'i', 'id', 'ie', 'if', "i'll", 'im', 'immediate', 'immediately', 'importance', 'important', 'in', 'inc', 'indeed', 'index', 'information', 'instead', 'into', 'invention', 'inward', 'is', "isn't", 'it', 'itd', "it'll", 'its', 'itself', "i've", 'j', 'just', 'k', 'keep\tkeeps', 'kept', 'kg', 'km', 'know', 'known', 'knows', 'l', 'largely', 'last', 'lately', 'later', 'latter', 'latterly', 'least', 'less', 'lest', 'let', 'lets', 'like', 'liked', 'likely', 'line', 'little', "'ll", 'look', 'looking', 'looks', 'ltd', 'm', 'made', 'mainly', 'make', 'makes', 'many', 'may', 'maybe', 'me', 'mean', 'means', 'meantime', 'meanwhile', 'merely', 'mg', 'might', 'million', 'miss', 'ml', 'more', 'moreover', 'most', 'mostly', 'mr', 'mrs', 'much', 'mug', 'must', 'my', 'myself', 'n', 'na', 'name', 'namely', 'nay', 'nd', 'near', 'nearly', 'necessarily', 'necessary', 'need', 'needs', 'neither', 'never', 'nevertheless', 'new', 'next', 'nine', 'ninety', 'no', 'nobody', 'non', 'none', 'nonetheless', 'noone', 'nor', 'normally', 'nos', 'not', 'noted', 'nothing', 'now', 'nowhere', 'o', 'obtain', 'obtained', 'obviously', 'of', 'off', 'often', 'oh', 'ok', 'okay', 'old', 'omitted', 'on', 'once', 'one', 'ones', 'only', 'onto', 'or', 'ord', 'other', 'others', 'otherwise', 'ought', 'our', 'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'owing', 'own', 'p', 'page', 'pages', 'part', 'particular', 'particularly', 'past', 'per', 'perhaps', 'placed', 'please', 'plus', 'poorly', 'possible', 'possibly', 'potentially', 'pp', 'predominantly', 'present', 'previously', 'primarily', 'probably', 'promptly', 'proud', 'provides', 'put', 'q', 'que', 'quickly', 'quite', 'qv', 'r', 'ran', 'rather', 'rd', 're', 'readily', 'really', 'recent', 'recently', 'ref', 'refs', 'regarding', 'regardless', 'regards', 'related', 'relatively', 'research', 'respectively', 'resulted', 'resulting', 'results', 'right', 'run', 's', 'said', 'same', 'saw', 'say', 'saying', 'says', 'sec', 'section', 'see', 'seeing', 'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves', 'sent', 'seven', 'several', 'shall', 'she', 'shed', "she'll", 'shes', 'should', "shouldn't", 'show', 'showed', 'shown', 'showns', 'shows', 'significant', 'significantly', 'similar', 'similarly', 'since', 'six', 'slightly', 'so', 'some', 'somebody', 'somehow', 'someone', 'somethan', 'something', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry', 'specifically', 'specified', 'specify', 'specifying', 'still', 'stop', 'strongly', 'sub', 'substantially', 'successfully', 'such', 'sufficiently', 'suggest', 'sup', 'sure\tt', 'take', 'taken', 'taking', 'tell', 'tends', 'th', 'than', 'thank', 'thanks', 'thanx', 'that', "that'll", 'thats', "that've", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 
             'thered', 'therefore', 'therein', "there'll", 'thereof', 'therere', 'theres', 'thereto', 'thereupon', "there've", 'these', 'they', 'theyd', "they'll", 'theyre', "they've", 'think', 'this', 'those', 'thou', 'though', 'though', 'thousand', 'throug', 'through', 'throughout', 'thru', 'thus', 'til', 'tip', 'to', 'together', 'too', 'took', 'toward', 'towards', 'tried', 'tries', 'truly', 'try', 'trying', 'ts', 'twice', 'two', 'u', 'un', 'under', 'unfortunately', 'unless', 'unlike', 'unlikely', 'until', 'unto', 'up', 'upon', 'ups', 'us', 'use', 'used', 'useful', 'usefully', 'usefulness', 'uses', 'using', 'usually', 'v', 'value', 'various', "'ve", 'very', 'via', 'viz', 'vol', 'vols', 'vs', 'w', 'want', 'wants', 'was', 'wasnt', 'way', 'we', 'wed', 'welcome', "we'll", 'went', 'were', 'werent', "we've", 'what', 'whatever', "what'll", 'whats', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby', 'wherein', 'wheres', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whim', 'whither', 'who', 'whod', 'whoever', 'whole', "who'll", 'whom', 'whomever', 'whos', 'whose', 'why', 'widely', 'willing', 'wish', 'with', 'within', 'without', 'wont', 'words', 'world', 'would', 'wouldnt', 'www', 'x', 'y', 'yes', 'yet', 'you', 'youd', "you'll", 'your', 'youre', 'yours', 'yourself', 'yourselves', "you've", 'z', 'zero']

        

stopwords_305 = stopwrd1
stopwords_747= list(set(stopwrd1 + stopwords2+ stopwords3 +stopwords4))
stopwords_710= stopwords_747[:710]

# %%
stopwords_507=stopwords_747[:int(305+(710-305)/2)]

# %% [markdown]
# ### SVM Classifier

# %%
def  predict(train_features, train_label, test_features): 
    """
    input: features for train and test instances and label for train instances
    
    returns prediction for instance and coefficient matrix and classifier
    
    """
    
    clf = LinearSVC()
    clf.fit(train_features, train_label)
    pred=clf.predict(test_features)
    coef = clf.coef_
    return pred, coef, clf

# %%
#NOTE

#using the SVM may create a non convergence warning, which does not affect the output 
#and cannot be fixed by an increase of iterations

# %% [markdown]
# ### Leave One Out Cross Validation

# %%
def get_LOO_instances(dataframe):
    """
    
    generates instances for LOO
    
    input: df
    
    output: list with instances as tuples: [(train_row, test_row)]
    
    """
    loo_instances=[]
    for instance in range(dataframe.shape[0]):
        inst= list(range(dataframe.shape[0]))
        inst.remove(instance)
        test=dataframe.drop(inst)
        train= dataframe.drop([instance])
        loo_instances.append((train, test))
    return loo_instances

# %%
#read in given data frame for 507 stop words
df = pd.read_excel("DataFrame_imp.xlsx")
#add Lemmas
old_df = pd.read_excel("DataFrame.xlsx")
df["Lemmas"] = old_df["Lemmas"]

# %%
#read in other data frame for other stop words
df = pd.read_excel("DataFrame.xlsx")

# %%
df
# Out:
#     Unnamed: 0  Play_id                                           Raw Text  \
# 0            0        0  As I remember , Adam , it was upon this fashio...
# 1            1        1  Proceed , Solinus , to procure my fall\nAnd by...
# 2            2        2  Who 's there ?\nNay , answer me : stand , and ...
# 3            3        3  So shaken as we are , so wan with care ,\nFind...
# 4            4        4  Open your ears ; for which of you will stop\nT...
# 5            5        5  O for a Muse of fire , that would ascend\nThe ...
# 6            6        6  Hung be the heavens with black , yield day to ...
# 7            7        7  As by your high imperial majesty\nI had in cha...
# 8            8        8  I wonder how the king escaped our hands .\nWhi...
# 9            9        9  Hence ! home , you idle creatures get you home...
# 10          10       10  Now , say , Chatillon , what would France with...
# 11          11       11  Let fame , that all hunt after in their lives ...
# 12          12       12  In sooth , I know not why I am so sad :\nIt we...
# 13          13       13  Sir Hugh , persuade me not ; I will make a Sta...
# 14          14       14  Now , fair Hippolyta , our nuptial hour\nDraws...
# 15          15       15  I learn in this letter that Don Peter of Arrag...
# 16          16       16  Old John of Gaunt , time-honour 'd Lancaster ,...
# 17          17       17  Now is the winter of our discontent\nMade glor...
# 18          18       18  Two households , both alike in dignity ,\nIn f...
# 19          19       19  I 'll pheeze you , in faith .\nA pair of stock...
# 20          20       20  Noble patricians , patrons of my right ,\nDefe...
# 21          21       21  If music be the food of love , play on ;\nGive...
# 22          22       22  Cease to persuade , my loving Proteus :\nHome-...
# 23          23       23  In delivering my son from me , I bury a second...
# 24          24       24  Nay , but this dotage of our general 's\nO'erf...
# 25          25       25  Before we proceed any further , hear me speak ...
# 26          26       26  You do not meet a man but frowns : our bloods\...
# 27          27       27  I come no more to make you laugh : things now ...
# 28          28       28  I thought the king had more affected the Duke ...
# 29          29       29  When shall we three meet again\nIn thunder , l...
# ..         ...      ...                                                ...
# 47          47       47  What Raynulph monk of Chester can\nRaise from ...
# 48          48       48  I am at my wit 's end , Savorwit .\nAnd I am e...
# 49          49       49  My lords ,\nKnow that we , far from any natura...
# 50          50       50  Thus high , my lords , your powers and constan...
# 51          51       51  My three years spent in war has now undone\nMy...
# 52          52       52  NOW o ' my Faith , Old Bishop Valen-\ntine ,\n...
# 53          53       53  such luck to spin out these fine things still ...
# 54          54       54  Sylla 's Ghost .\nDOst thou not feel me , Rome...
# 55          55       55  ' Tis I , blind Archer .\nWho ?\nMercury ?\nSt...
# 56          56       56  Brain-worm ,\nCall up your young master : bid ...
# 57          57       57  I Would , I could make 'hem a shew my self . I...
# 58          58       58  95\nP O E T A S T E R:\nO R,\nHis Arraignment ...
# 59          59       59  Thy worst .\nI fart at thee .\nHa' you your Wi...
# 60          60       60  YOU woful wights , give ear a\nwhile ,\nAnd ma...
# 61          61       61  To Earth ?\nand why to Earth , thou foolish\nS...
# 62          62       62  Welcome , good Captain Ironside , and Bro-\nth...
# 63          63       63  The SCENE\nB A R N E T.\nThe P E R S O N S of ...
# 64          64       64  he walks in his Gown , Wastcoat , and Trousers...
# 65          65       65  Open the Shrine , that I may see my Saint .\nH...
# 66          66       66  \nCan one self cause , in subjects so alike As...
# 67          67       67  An Humorous Day 's Mirth .\nLa , Yet hath the ...
# 68          68       68  \nLeave me awhile , my lords , and wait for me...
# 69          69       69  \nFortune , not Reason , rules the state of th...
# 70          70       70  Byron fall 'n in so traitorous a re - lapse , ...
# 71          71       71  Sc?na prima .\nof the first day . Loose no tim...
# 72          72       72  \nMonsieur D'Olive .\nPhilip , the Duke .\nAnn...
# 73          73       73  \nTo what will this declining kingdom turn , S...
# 74          74       74  VVhere is Sir Gyles Goosecappe here ?\nHere my...
# 75          75       75  \nHaste , nephew 1 what , a sluggard ?\nFie fo...
# 76          76       76  \nThou blind imperfect goddess , that delight ...
#
#                                               POS_305  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT NOUN SPACE VE...
# 1    PROPN PUNCT PROPN PUNCT VERB NOUN SPACE CCONJ...
# 2    NOUN VERB PUNCT SPACE PROPN PUNCT VERB PUNCT ...
# 3    ADV VERB PUNCT NOUN NOUN PUNCT SPACE VERB NOU...
# 4    VERB NOUN PUNCT VERB SPACE DET NOUN VERB ADJ ...
# 5    INTJ PROPN NOUN PUNCT VERB SPACE DET ADJ PROP...
# 6    PROPN NOUN ADJ PUNCT NOUN NOUN NOUN PUNCT SPA...
# 7    ADP ADJ ADJ NOUN SPACE PRON NOUN NOUN PROPN P...
# 8    PRON VERB NOUN VERB NOUN PUNCT SPACE ADP VERB...
# 9    ADV PUNCT ADV PUNCT ADJ NOUN ADV PUNCT SPACE ...
# 10   ADV PUNCT PUNCT PROPN PUNCT PROPN PUNCT SPACE...
# 11   VERB NOUN PUNCT NOUN NOUN PUNCT SPACE PROPN N...
# 12   ADP NOUN PUNCT PRON VERB PRON ADJ PUNCT SPACE...
# 13   PROPN PROPN PUNCT VERB PUNCT PRON ADJ SPACE N...
# 14   ADV PUNCT ADJ PROPN PUNCT ADJ NOUN SPACE VERB...
# 15   PRON VERB NOUN PROPN PROPN PROPN SPACE VERB N...
# 16   PROPN PROPN PROPN PUNCT NOUN PUNCT NOUN PROPN...
# 17   ADV NOUN NOUN SPACE VERB ADJ NOUN NOUN PROPN ...
# 18   NUM NOUN PUNCT ADV NOUN PUNCT SPACE ADP ADJ P...
# 19   PRON VERB VERB PUNCT NOUN PUNCT SPACE DET NOU...
# 20   ADJ NOUN PUNCT NOUN NOUN PUNCT SPACE VERB NOU...
# 21   ADP NOUN NOUN NOUN PUNCT VERB PUNCT SPACE VER...
# 22   VERB VERB PUNCT VERB PROPN PUNCT SPACE NOUN P...
# 23   ADP VERB NOUN PUNCT PRON VERB ADJ NOUN PUNCT ...
# 24   INTJ PUNCT NOUN NOUN PART SPACE VERB NOUN PUN...
# 25   ADP VERB PUNCT VERB VERB PUNCT SPACE PROPN PU...
# 26   PRON VERB NOUN VERB PUNCT NOUN SPACE ADV VERB...
# 27   PRON VERB VERB PUNCT NOUN PUNCT SPACE ADJ VER...
# 28   PRON VERB NOUN VERB PROPN SPACE PROPN PROPN P...
# 29   ADV VERB VERB SPACE ADP NOUN PUNCT NOUN PUNCT...
# ..                                                ...
# 47   NOUN PROPN NOUN PROPN SPACE PROPN SPACE ADJ V...
# 48   PRON NOUN PART NOUN PUNCT PROPN PUNCT SPACE C...
# 49   ADJ NOUN PUNCT SPACE VERB PUNCT ADV ADJ NOUN ...
# 50   ADV ADJ PUNCT NOUN PUNCT NOUN ADJ NOUN SPACE ...
# 51   ADJ NOUN VERB NOUN VERB SPACE ADJ NOUN ADV PU...
# 52   ADV INTJ PUNCT NOUN PUNCT PROPN PROPN PROPN S...
# 53   NOUN VERB ADJ NOUN PUNCT SPACE ADP NOUN PUNCT...
# 54   PROPN PART PROPN PUNCT SPACE PROPN VERB VERB ...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB ADJ NOUN PUN...
# 57   PRON VERB PUNCT PRON PUNCT VERB NOUN NOUN PUN...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB PRON PUNCT SPA...
# 60   PRON ADJ NOUN PUNCT X SPACE PUNCT SPACE CCONJ...
# 61   ADP PROPN PUNCT SPACE PROPN PUNCT VERB ADJ SP...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT PROPN SPACE ...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   VERB PROPN PUNCT PROPN PUNCT PROPN PUNCT NUM ...
# 65   VERB PROPN PUNCT PRON PROPN PUNCT SPACE PROPN...
# 66   SPACE VERB NOUN VERB PUNCT NOUN ADV ADP PUNCT...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB ADV PUNCT NOUN PUNCT VERB ADP ADJ ...
# 69   SPACE PROPN PUNCT NOUN PUNCT VERB NOUN NOUN P...
# 70   PROPN VERB PUNCT CCONJ ADJ PUNCT NOUN PUNCT V...
# 71   NOUN NOUN PUNCT SPACE NOUN PUNCT ADJ NOUN NOU...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT PRO...
# 73   SPACE ADP VERB NOUN NOUN PUNCT VERB NOUN PUNC...
# 74   PROPN PROPN PROPN PROPN PUNCT SPACE ADV PROPN...
# 75   SPACE PROPN PUNCT NOUN NUM PUNCT ADJ PUNCT SP...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT NOUN PUNCT INT...
#
#                                               POS_710  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT VERB NOUN SPA...
# 1    PROPN PUNCT PROPN PUNCT VERB NOUN SPACE CCONJ...
# 2    NOUN VERB PUNCT SPACE PROPN PUNCT VERB PUNCT ...
# 3    ADV VERB PUNCT NOUN NOUN PUNCT SPACE VERB NOU...
# 4    VERB NOUN PUNCT SPACE DET NOUN VERB ADJ PROPN...
# 5    INTJ PROPN NOUN PUNCT VERB SPACE DET ADJ PROP...
# 6    PROPN NOUN ADJ PUNCT NOUN NOUN NOUN PUNCT SPA...
# 7    ADP ADJ ADJ NOUN SPACE PRON NOUN ADP NOUN PRO...
# 8    PRON VERB NOUN VERB NOUN PUNCT SPACE ADP VERB...
# 9    ADV PUNCT PUNCT ADJ NOUN PUNCT SPACE VERB NOU...
# 10   ADV PUNCT PUNCT PROPN PUNCT PROPN PUNCT SPACE...
# 11   VERB NOUN PUNCT NOUN NOUN PUNCT SPACE PROPN N...
# 12   ADP NOUN PUNCT PRON PRON VERB ADJ PUNCT SPACE...
# 13   PROPN PROPN PUNCT VERB PUNCT PRON ADJ SPACE N...
# 14   ADV PUNCT ADJ PROPN PUNCT ADJ NOUN SPACE VERB...
# 15   PRON VERB NOUN PROPN PROPN PROPN SPACE NOUN P...
# 16   PROPN PROPN PROPN PUNCT NOUN PUNCT NOUN PROPN...
# 17   ADV NOUN NOUN SPACE VERB ADJ NOUN NOUN PROPN ...
# 18   NUM NOUN PUNCT ADV NOUN PUNCT SPACE ADP ADJ P...
# 19   PRON VERB PUNCT NOUN PUNCT SPACE DET NOUN NOU...
# 20   ADJ NOUN PUNCT NOUN NOUN PUNCT SPACE VERB NOU...
# 21   ADP NOUN NOUN NOUN PUNCT VERB PUNCT SPACE VER...
# 22   VERB VERB PUNCT VERB PROPN PUNCT SPACE NOUN P...
# 23   ADP VERB NOUN PUNCT PRON VERB ADJ NOUN PUNCT ...
# 24   INTJ PUNCT NOUN NOUN PART SPACE VERB NOUN PUN...
# 25   ADP VERB PUNCT VERB VERB PUNCT SPACE PROPN PU...
# 26   PRON VERB NOUN VERB PUNCT NOUN SPACE ADV VERB...
# 27   PRON VERB PUNCT NOUN PUNCT SPACE ADJ VERB NOU...
# 28   PRON VERB NOUN PROPN SPACE PROPN PROPN PUNCT ...
# 29   ADV NUM VERB SPACE ADP NOUN PUNCT NOUN PUNCT ...
# ..                                                ...
# 47   NOUN PROPN NOUN PROPN SPACE PROPN SPACE ADJ V...
# 48   PRON VERB ADP NOUN PART PUNCT PROPN PUNCT SPA...
# 49   ADJ NOUN PUNCT SPACE VERB PUNCT ADJ NOUN PUNC...
# 50   ADV ADJ PUNCT NOUN PUNCT NOUN ADJ NOUN SPACE ...
# 51   ADJ NUM NOUN VERB NOUN VERB SPACE ADJ NOUN AD...
# 52   ADV PUNCT NOUN PUNCT PROPN PROPN PROPN SPACE ...
# 53   NOUN VERB ADJ NOUN PUNCT SPACE NOUN PUNCT NOU...
# 54   PROPN PART PROPN PUNCT SPACE PROPN VERB PUNCT...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB ADJ NOUN PUN...
# 57   PRON VERB PUNCT PRON PUNCT VERB NOUN PUNCT AD...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB ADP PRON PUNCT...
# 60   PRON ADJ NOUN PUNCT X SPACE PUNCT SPACE CCONJ...
# 61   ADP PROPN PUNCT SPACE PROPN PUNCT ADJ SPACE P...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT PROPN SPACE ...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   VERB PROPN PUNCT PROPN PUNCT PROPN PUNCT NUM ...
# 65   VERB PROPN PUNCT PRON PROPN PUNCT SPACE PROPN...
# 66   SPACE VERB PUNCT NOUN ADV ADP PUNCT VERB PUNC...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB ADV PUNCT NOUN PUNCT VERB ADP ADJ ...
# 69   SPACE PROPN PUNCT NOUN PUNCT VERB NOUN NOUN P...
# 70   PROPN VERB PUNCT ADJ PUNCT NOUN PUNCT VERB NO...
# 71   NOUN NOUN PUNCT SPACE NOUN PUNCT ADJ NOUN NOU...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT PRO...
# 73   SPACE ADP VERB NOUN NOUN PUNCT VERB DET NOUN ...
# 74   PROPN PROPN PROPN PROPN PUNCT SPACE ADV PROPN...
# 75   SPACE PROPN PUNCT NOUN NUM PUNCT ADJ PUNCT SP...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT NOUN PUNCT INT...
#
#                                               POS_747  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT NOUN SPACE VE...
# 1    PROPN PUNCT PROPN PUNCT VERB NOUN SPACE CCONJ...
# 2    NOUN VERB PUNCT SPACE PROPN PUNCT VERB PUNCT ...
# 3    ADV VERB PUNCT NOUN NOUN PUNCT SPACE VERB NOU...
# 4    VERB NOUN PUNCT SPACE DET NOUN VERB ADJ PROPN...
# 5    INTJ PROPN NOUN PUNCT VERB SPACE DET ADJ PROP...
# 6    PROPN NOUN ADJ PUNCT NOUN NOUN NOUN PUNCT SPA...
# 7    ADP ADJ ADJ NOUN SPACE PRON NOUN NOUN PROPN P...
# 8    PRON VERB NOUN VERB NOUN PUNCT SPACE ADP VERB...
# 9    ADV PUNCT PUNCT ADJ NOUN PUNCT SPACE VERB NOU...
# 10   ADV PUNCT PUNCT PROPN PUNCT PROPN PUNCT SPACE...
# 11   VERB NOUN PUNCT NOUN NOUN PUNCT SPACE PROPN N...
# 12   ADP NOUN PUNCT PRON PRON ADJ PUNCT SPACE PRON...
# 13   PROPN PROPN PUNCT VERB PUNCT PRON ADJ SPACE N...
# 14   ADV PUNCT ADJ PROPN PUNCT ADJ NOUN SPACE VERB...
# 15   PRON VERB NOUN PROPN PROPN PROPN SPACE NOUN P...
# 16   PROPN PROPN PROPN PUNCT NOUN PUNCT NOUN PROPN...
# 17   ADV NOUN NOUN SPACE VERB ADJ NOUN NOUN PROPN ...
# 18   NUM NOUN PUNCT ADV NOUN PUNCT SPACE ADP ADJ P...
# 19   PRON VERB PUNCT NOUN PUNCT SPACE DET NOUN NOU...
# 20   ADJ NOUN PUNCT NOUN PUNCT SPACE VERB NOUN NOU...
# 21   ADP NOUN NOUN NOUN PUNCT VERB PUNCT SPACE VER...
# 22   VERB VERB PUNCT VERB PROPN PUNCT SPACE NOUN P...
# 23   ADP VERB NOUN PUNCT PRON VERB ADJ NOUN PUNCT ...
# 24   INTJ PUNCT NOUN NOUN PART SPACE VERB NOUN PUN...
# 25   ADP VERB PUNCT VERB VERB PUNCT SPACE PROPN PU...
# 26   PRON VERB NOUN VERB PUNCT NOUN SPACE ADV VERB...
# 27   PRON VERB PUNCT NOUN PUNCT SPACE ADJ VERB NOU...
# 28   PRON VERB NOUN PROPN SPACE PROPN PROPN PUNCT ...
# 29   ADV VERB SPACE ADP NOUN PUNCT NOUN PUNCT NOUN...
# ..                                                ...
# 47   NOUN PROPN NOUN PROPN SPACE PROPN SPACE ADJ V...
# 48   PRON NOUN PART PUNCT PROPN PUNCT SPACE CCONJ ...
# 49   ADJ NOUN PUNCT SPACE VERB PUNCT ADJ NOUN PUNC...
# 50   ADV ADJ PUNCT NOUN PUNCT NOUN ADJ NOUN SPACE ...
# 51   ADJ NOUN VERB NOUN VERB SPACE ADJ NOUN ADV PU...
# 52   ADV PUNCT NOUN PUNCT PROPN PROPN PROPN SPACE ...
# 53   NOUN VERB ADJ NOUN PUNCT SPACE NOUN PUNCT NOU...
# 54   PROPN PART PROPN PUNCT SPACE PROPN VERB PUNCT...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB ADJ NOUN PUN...
# 57   PRON VERB PUNCT PRON PUNCT VERB NOUN PUNCT AD...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB PRON PUNCT SPA...
# 60   PRON ADJ NOUN PUNCT X SPACE PUNCT SPACE CCONJ...
# 61   ADP PROPN PUNCT SPACE PROPN PUNCT ADJ SPACE P...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT PROPN SPACE ...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   VERB PROPN PUNCT PROPN PUNCT PROPN PUNCT NUM ...
# 65   VERB PROPN PUNCT PRON PROPN PUNCT SPACE PROPN...
# 66   SPACE VERB PUNCT NOUN ADV ADP PUNCT VERB PUNC...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB ADV PUNCT NOUN PUNCT VERB ADP ADJ ...
# 69   SPACE PROPN PUNCT NOUN PUNCT VERB NOUN NOUN P...
# 70   PROPN VERB PUNCT ADJ PUNCT NOUN PUNCT VERB NO...
# 71   NOUN NOUN PUNCT SPACE NOUN PUNCT ADJ NOUN NOU...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT PRO...
# 73   SPACE ADP VERB NOUN NOUN PUNCT VERB NOUN PUNC...
# 74   PROPN PROPN PROPN PROPN PUNCT SPACE ADV PROPN...
# 75   SPACE PROPN PUNCT NOUN NUM PUNCT ADJ PUNCT SP...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT NOUN PUNCT INT...
#
#                                          POSstops_305  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it was upon t...
# 1    PROPN PUNCT PROPN PUNCT to VERB my NOUN SPACE...
# 2    NOUN VERB there PUNCT SPACE PROPN PUNCT VERB ...
# 3    ADV VERB as we are PUNCT so NOUN with NOUN PU...
# 4    VERB your NOUN PUNCT for which of you will VE...
# 5    INTJ for a PROPN of NOUN PUNCT that would VER...
# 6    PROPN be the NOUN with ADJ PUNCT NOUN NOUN to...
# 7    ADP by your ADJ ADJ NOUN SPACE PRON had in NO...
# 8    PRON VERB how the NOUN VERB our NOUN PUNCT SP...
# 9    ADV PUNCT ADV PUNCT you ADJ NOUN get you ADV ...
# 10   ADV PUNCT say PUNCT PROPN PUNCT what would PR...
# 11   VERB NOUN PUNCT that all NOUN after in their ...
# 12   ADP NOUN PUNCT PRON VERB not why PRON am so A...
# 13   PROPN PROPN PUNCT VERB me not PUNCT PRON will...
# 14   ADV PUNCT ADJ PROPN PUNCT our ADJ NOUN SPACE ...
# 15   PRON VERB in this NOUN that PROPN PROPN of PR...
# 16   PROPN PROPN of PROPN PUNCT NOUN PUNCT NOUN PR...
# 17   ADV is the NOUN of our NOUN SPACE VERB ADJ NO...
# 18   NUM NOUN PUNCT both ADV in NOUN PUNCT SPACE A...
# 19   PRON VERB VERB you PUNCT in NOUN PUNCT SPACE ...
# 20   ADJ NOUN PUNCT NOUN of my NOUN PUNCT SPACE VE...
# 21   ADP NOUN be the NOUN of NOUN PUNCT VERB on PU...
# 22   VERB to VERB PUNCT my VERB PROPN PUNCT SPACE ...
# 23   ADP VERB my NOUN from me PUNCT PRON VERB a AD...
# 24   INTJ PUNCT but this NOUN of our NOUN PART SPA...
# 25   ADP we VERB any further PUNCT VERB me VERB PU...
# 26   PRON do not VERB a NOUN but VERB PUNCT our NO...
# 27   PRON VERB no more to make you VERB PUNCT NOUN...
# 28   PRON VERB the NOUN had more VERB the PROPN of...
# 29   ADV VERB we three VERB again SPACE ADP NOUN P...
# ..                                                ...
# 47   NOUN PROPN NOUN of PROPN can SPACE PROPN from...
# 48   PRON am at my NOUN PART NOUN PUNCT PROPN PUNC...
# 49   ADJ NOUN PUNCT SPACE VERB that we PUNCT ADV f...
# 50   ADV ADJ PUNCT my NOUN PUNCT your NOUN and ADJ...
# 51   ADJ three NOUN VERB in NOUN has now VERB SPAC...
# 52   ADV INTJ PUNCT my NOUN PUNCT PROPN PROPN PROP...
# 53   such NOUN to VERB out these ADJ NOUN still PU...
# 54   PROPN PART PROPN PUNCT SPACE PROPN VERB not V...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB up your ADJ ...
# 57   PRON VERB PUNCT PRON could make PUNCT VERB a ...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB at PRON PUNCT ...
# 60   PRON ADJ NOUN PUNCT give X a SPACE while PUNC...
# 61   ADP PROPN PUNCT SPACE and why to PROPN PUNCT ...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT and PROPN SP...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   he VERB in his PROPN PUNCT PROPN PUNCT and PR...
# 65   VERB the PROPN PUNCT that PRON may see my PRO...
# 66   SPACE VERB one NOUN VERB PUNCT in NOUN so ADV...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB me ADV PUNCT my NOUN PUNCT and VER...
# 69   SPACE PROPN PUNCT not NOUN PUNCT VERB the NOU...
# 70   PROPN VERB PUNCT CCONJ in so ADJ a re PUNCT N...
# 71   NOUN NOUN PUNCT SPACE of the first NOUN PUNCT...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT the...
# 73   SPACE ADP what will this VERB NOUN NOUN PUNCT...
# 74   PROPN is PROPN PROPN PROPN here PUNCT SPACE A...
# 75   SPACE PROPN PUNCT NOUN NUM what PUNCT a ADJ P...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT that NOUN PUNC...
#
#                                          POSstops_710  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it VERB upon ...
# 1    PROPN PUNCT PROPN PUNCT to VERB my NOUN SPACE...
# 2    NOUN VERB there PUNCT SPACE PROPN PUNCT VERB ...
# 3    ADV VERB as we are PUNCT so NOUN with NOUN PU...
# 4    VERB your NOUN PUNCT for which of you will st...
# 5    INTJ for a PROPN of NOUN PUNCT that would VER...
# 6    PROPN be the NOUN with ADJ PUNCT NOUN NOUN to...
# 7    ADP by your ADJ ADJ NOUN SPACE PRON had in NO...
# 8    PRON VERB how the NOUN VERB our NOUN PUNCT SP...
# 9    ADV PUNCT home PUNCT you ADJ NOUN get you hom...
# 10   ADV PUNCT say PUNCT PROPN PUNCT what would PR...
# 11   VERB NOUN PUNCT that all NOUN after in their ...
# 12   ADP NOUN PUNCT PRON know not why PRON VERB so...
# 13   PROPN PROPN PUNCT VERB me not PUNCT PRON will...
# 14   ADV PUNCT ADJ PROPN PUNCT our ADJ NOUN SPACE ...
# 15   PRON VERB in this NOUN that PROPN PROPN of PR...
# 16   PROPN PROPN of PROPN PUNCT NOUN PUNCT NOUN PR...
# 17   ADV is the NOUN of our NOUN SPACE VERB ADJ NO...
# 18   NUM NOUN PUNCT both ADV in NOUN PUNCT SPACE A...
# 19   PRON 'll VERB you PUNCT in NOUN PUNCT SPACE D...
# 20   ADJ NOUN PUNCT NOUN of my NOUN PUNCT SPACE VE...
# 21   ADP NOUN be the NOUN of NOUN PUNCT VERB on PU...
# 22   VERB to VERB PUNCT my VERB PROPN PUNCT SPACE ...
# 23   ADP VERB my NOUN from me PUNCT PRON VERB a AD...
# 24   INTJ PUNCT but this NOUN of our NOUN PART SPA...
# 25   ADP we VERB any further PUNCT VERB me VERB PU...
# 26   PRON do not VERB a NOUN but VERB PUNCT our NO...
# 27   PRON come no more to make you VERB PUNCT NOUN...
# 28   PRON VERB the NOUN had more affected the PROP...
# 29   ADV shall we NUM VERB again SPACE ADP NOUN PU...
# ..                                                ...
# 47   NOUN PROPN NOUN of PROPN can SPACE PROPN from...
# 48   PRON VERB ADP my NOUN PART end PUNCT PROPN PU...
# 49   ADJ NOUN PUNCT SPACE VERB that we PUNCT far f...
# 50   ADV ADJ PUNCT my NOUN PUNCT your NOUN and ADJ...
# 51   ADJ NUM NOUN VERB in NOUN has now VERB SPACE ...
# 52   ADV o PUNCT my NOUN PUNCT PROPN PROPN PROPN S...
# 53   such NOUN to VERB out these ADJ NOUN still PU...
# 54   PROPN PART PROPN PUNCT SPACE PROPN thou not V...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB up your ADJ ...
# 57   PRON VERB PUNCT PRON could make PUNCT VERB a ...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB ADP PRON PUNCT...
# 60   PRON ADJ NOUN PUNCT give X a SPACE while PUNC...
# 61   ADP PROPN PUNCT SPACE and why to PROPN PUNCT ...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT and PROPN SP...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   he VERB in his PROPN PUNCT PROPN PUNCT and PR...
# 65   VERB the PROPN PUNCT that PRON may see my PRO...
# 66   SPACE VERB one self cause PUNCT in NOUN so AD...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB me ADV PUNCT my NOUN PUNCT and VER...
# 69   SPACE PROPN PUNCT not NOUN PUNCT VERB the NOU...
# 70   PROPN VERB PUNCT n in so ADJ a re PUNCT NOUN ...
# 71   NOUN NOUN PUNCT SPACE of the first NOUN PUNCT...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT the...
# 73   SPACE ADP what will this VERB NOUN NOUN PUNCT...
# 74   PROPN is PROPN PROPN PROPN here PUNCT SPACE A...
# 75   SPACE PROPN PUNCT NOUN NUM what PUNCT a ADJ P...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT that NOUN PUNC...
#
#                                          POSstops_747  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it was upon t...
# 1    PROPN PUNCT PROPN PUNCT to VERB my NOUN SPACE...
# 2    NOUN VERB there PUNCT SPACE PROPN PUNCT VERB ...
# 3    ADV VERB as we are PUNCT so NOUN with NOUN PU...
# 4    VERB your NOUN PUNCT for which of you will st...
# 5    INTJ for a PROPN of NOUN PUNCT that would VER...
# 6    PROPN be the NOUN with ADJ PUNCT NOUN NOUN to...
# 7    ADP by your ADJ ADJ NOUN SPACE PRON had in NO...
# 8    PRON VERB how the NOUN VERB our NOUN PUNCT SP...
# 9    ADV PUNCT home PUNCT you ADJ NOUN get you hom...
# 10   ADV PUNCT say PUNCT PROPN PUNCT what would PR...
# 11   VERB NOUN PUNCT that all NOUN after in their ...
# 12   ADP NOUN PUNCT PRON know not why PRON am so A...
# 13   PROPN PROPN PUNCT VERB me not PUNCT PRON will...
# 14   ADV PUNCT ADJ PROPN PUNCT our ADJ NOUN SPACE ...
# 15   PRON VERB in this NOUN that PROPN PROPN of PR...
# 16   PROPN PROPN of PROPN PUNCT NOUN PUNCT NOUN PR...
# 17   ADV is the NOUN of our NOUN SPACE VERB ADJ NO...
# 18   NUM NOUN PUNCT both ADV in NOUN PUNCT SPACE A...
# 19   PRON 'll VERB you PUNCT in NOUN PUNCT SPACE D...
# 20   ADJ NOUN PUNCT NOUN of my right PUNCT SPACE V...
# 21   ADP NOUN be the NOUN of NOUN PUNCT VERB on PU...
# 22   VERB to VERB PUNCT my VERB PROPN PUNCT SPACE ...
# 23   ADP VERB my NOUN from me PUNCT PRON VERB a AD...
# 24   INTJ PUNCT but this NOUN of our NOUN PART SPA...
# 25   ADP we VERB any further PUNCT VERB me VERB PU...
# 26   PRON do not VERB a NOUN but VERB PUNCT our NO...
# 27   PRON come no more to make you VERB PUNCT NOUN...
# 28   PRON VERB the NOUN had more affected the PROP...
# 29   ADV shall we three VERB again SPACE ADP NOUN ...
# ..                                                ...
# 47   NOUN PROPN NOUN of PROPN can SPACE PROPN from...
# 48   PRON am at my NOUN PART end PUNCT PROPN PUNCT...
# 49   ADJ NOUN PUNCT SPACE VERB that we PUNCT far f...
# 50   ADV ADJ PUNCT my NOUN PUNCT your NOUN and ADJ...
# 51   ADJ three NOUN VERB in NOUN has now VERB SPAC...
# 52   ADV o PUNCT my NOUN PUNCT PROPN PROPN PROPN S...
# 53   such NOUN to VERB out these ADJ NOUN still PU...
# 54   PROPN PART PROPN PUNCT SPACE PROPN thou not V...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB up your ADJ ...
# 57   PRON VERB PUNCT PRON could make PUNCT VERB a ...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB at PRON PUNCT ...
# 60   PRON ADJ NOUN PUNCT give X a SPACE while PUNC...
# 61   ADP PROPN PUNCT SPACE and why to PROPN PUNCT ...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT and PROPN SP...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   he VERB in his PROPN PUNCT PROPN PUNCT and PR...
# 65   VERB the PROPN PUNCT that PRON may see my PRO...
# 66   SPACE VERB one self cause PUNCT in NOUN so AD...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB me ADV PUNCT my NOUN PUNCT and VER...
# 69   SPACE PROPN PUNCT not NOUN PUNCT VERB the NOU...
# 70   PROPN VERB PUNCT n in so ADJ a re PUNCT NOUN ...
# 71   NOUN NOUN PUNCT SPACE of the first NOUN PUNCT...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT the...
# 73   SPACE ADP what will this VERB NOUN NOUN PUNCT...
# 74   PROPN is PROPN PROPN PROPN here PUNCT SPACE A...
# 75   SPACE PROPN PUNCT NOUN NUM what PUNCT a ADJ P...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT that NOUN PUNC...
#
#                                                Lemmas  Label         Author  \
# 0    as -PRON- remember , adam , -PRON- be upon th...      0  E-Shakespeare
# 1    proceed , solinus , to procure -PRON- fall \n...      0  E-Shakespeare
# 2    who be there ? \n nay , answer -PRON- : stand...      0  E-Shakespeare
# 3    so shake as -PRON- be , so wan with care , \n...      0  E-Shakespeare
# 4    open -PRON- ear ; for which of -PRON- will st...      0  E-Shakespeare
# 5    o for a muse of fire , that would ascend \n t...      0  E-Shakespeare
# 6    hung be the heaven with black , yield day to ...      0  E-Shakespeare
# 7    as by -PRON- high imperial majesty \n -PRON- ...      0  E-Shakespeare
# 8    -PRON- wonder how the king escape -PRON- hand...      0  E-Shakespeare
# 9    hence ! home , -PRON- idle creature get -PRON...      0  E-Shakespeare
# 10   now , say , chatillon , what would france wit...      0  E-Shakespeare
# 11   let fame , that all hunt after in -PRON- life...      0  E-Shakespeare
# 12   in sooth , -PRON- know not why -PRON- be so s...      0  E-Shakespeare
# 13   sir hugh , persuade -PRON- not ; -PRON- will ...      0  E-Shakespeare
# 14   now , fair hippolyta , -PRON- nuptial hour \n...      0  E-Shakespeare
# 15   -PRON- learn in this letter that don peter of...      0  E-Shakespeare
# 16   old john of gaunt , time - honour 'd lancaste...      0  E-Shakespeare
# 17   now be the winter of -PRON- discontent \n mak...      0  E-Shakespeare
# 18   two household , both alike in dignity , \n in...      0  E-Shakespeare
# 19   -PRON- will pheeze -PRON- , in faith . \n a p...      0  E-Shakespeare
# 20   noble patrician , patron of -PRON- right , \n...      0  E-Shakespeare
# 21   if music be the food of love , play on ; \n g...      0  E-Shakespeare
# 22   cease to persuade , -PRON- love proteus : \n ...      0  E-Shakespeare
# 23   in deliver -PRON- son from -PRON- , -PRON- bu...      1  L-Shakespeare
# 24   nay , but this dotage of -PRON- general 's \n...      1  L-Shakespeare
# 25   before -PRON- proceed any further , hear -PRO...      1  L-Shakespeare
# 26   -PRON- do not meet a man but frown : -PRON- b...      1  L-Shakespeare
# 27   -PRON- come no more to make -PRON- laugh : th...      1  L-Shakespeare
# 28   -PRON- think the king have more affect the du...      1  L-Shakespeare
# 29   when shall -PRON- three meet again \n in thun...      1  L-Shakespeare
# ..                                                ...    ...            ...
# 47   what raynulph monk of chester can \n raise fr...      3      Middleton
# 48   -PRON- be at -PRON- wit 's end , savorwit . \...      3      Middleton
# 49   -PRON- lord , \n know that -PRON- , far from ...      3      Middleton
# 50   thus high , -PRON- lord , -PRON- power and co...      3      Middleton
# 51   -PRON- three year spend in war have now undo ...      3      Middleton
# 52   now o ' -PRON- faith , old bishop valen- \n t...      4         Jonson
# 53   such luck to spin out these fine thing still ...      4         Jonson
# 54   sylla 's ghost . \n dost thou not feel -PRON-...      4         Jonson
# 55   ' tis -PRON- , blind archer . \n who ? \n mer...      4         Jonson
# 56   brain - worm , \n call up -PRON- young master...      4         Jonson
# 57   -PRON- would , -PRON- could make ' hem a shew...      4         Jonson
# 58   95 \n p o e t a s t e r : \n o r , \n -PRON- ...      4         Jonson
# 59   thy bad . \n -PRON- fart at thee . \n ha ' -P...      4         Jonson
# 60   you woful wight , give ear a \n while , \n an...      4         Jonson
# 61   to earth ? \n and why to earth , thou foolish...      4         Jonson
# 62   welcome , good captain ironside , and bro- \n...      4         Jonson
# 63   the scene \n b a r n e t. \n the p e r s o n ...      4         Jonson
# 64   -PRON- walk in -PRON- gown , wastcoat , and t...      4         Jonson
# 65   open the shrine , that -PRON- may see -PRON- ...      4         Jonson
# 66   \n can one self because , in subject so alike...      5        Chapman
# 67   an humorous day 's mirth . \n la , yet hath t...      5        Chapman
# 68   \n leave -PRON- awhile , -PRON- lord , and wa...      5        Chapman
# 69   \n fortune , not reason , rule the state of t...      5        Chapman
# 70   byron fall ' n in so traitorous a re - lapse ...      5        Chapman
# 71   sc?na prima . \n of the first day . loose no ...      5        Chapman
# 72   \n monsieur d'olive . \n philip , the duke . ...      5        Chapman
# 73   \n to what will this decline kingdom turn , s...      5        Chapman
# 74   vvhere be sir gyles goosecappe here ? \n here...      5        Chapman
# 75   \n haste , nephew 1 what , a sluggard ? \n fi...      5        Chapman
# 76   \n thou blind imperfect goddess , that deligh...      5        Chapman
#
#                                         Play
# 0          asyoulikeit.txt.E-Shakespeare.tok
# 1        comedy_errors.txt.E-Shakespeare.tok
# 2               Hamlet.txt.E-Shakespeare.tok
# 3         henryivPart1.txt.E-Shakespeare.tok
# 4         henryivPart2.txt.E-Shakespeare.tok
# 5               henryv.txt.E-Shakespeare.tok
# 6         henryviPart1.txt.E-Shakespeare.tok
# 7         henryviPart2.txt.E-Shakespeare.tok
# 8         henryviPart3.txt.E-Shakespeare.tok
# 9        julius_caesar.txt.E-Shakespeare.tok
# 10           King John.txt.E-Shakespeare.tok
# 11   Love_Labours_lost.txt.E-Shakespeare.tok
# 12     merchant-venice.txt.E-Shakespeare.tok
# 13         merry_wives.txt.E-Shakespeare.tok
# 14           midsummer.txt.E-Shakespeare.tok
# 15            much_ado.txt.E-Shakespeare.tok
# 16           richardii.txt.E-Shakespeare.tok
# 17          richardiii.txt.E-Shakespeare.tok
# 18        romeo_juliet.txt.E-Shakespeare.tok
# 19        taming_shrew.txt.E-Shakespeare.tok
# 20    Titus_Andronicus.txt.E-Shakespeare.tok
# 21       twelfth_night.txt.E-Shakespeare.tok
# 22       two_gentlemen.txt.E-Shakespeare.tok
# 23            allswell.txt.L-Shakespeare.tok
# 24           Cleopatra.txt.L-Shakespeare.tok
# 25          coriolanus.txt.L-Shakespeare.tok
# 26           Cymbeline.txt.L-Shakespeare.tok
# 27           henryviii.txt.L-Shakespeare.tok
# 28                Lear.txt.L-Shakespeare.tok
# 29             Macbeth.txt.L-Shakespeare.tok
# ..                                       ...
# 47                 hengist.txt.Middleton.tok
# 48                  no wit.txt.Middleton.tok
# 49                 Phoenix.txt.Middleton.tok
# 50       the second maiden.txt.Middleton.tok
# 51               the witch.txt.Middleton.tok
# 52            A Tale of a Tub.txt.Jonson.tok
# 53            Bartholmew Fair.txt.Jonson.tok
# 54    Catiline His Conspiracy.txt.Jonson.tok
# 55            Cynthias Revels.txt.Jonson.tok
# 56    Every Man in his Humour.txt.Jonson.tok
# 57              Love_Restored.txt.Jonson.tok
# 58                  Poetaster.txt.Jonson.tok
# 59              The Alchemist.txt.Jonson.tok
# 60        THE CASE IS ALTERED.txt.Jonson.tok
# 61        The Devil is an Ass.txt.Jonson.tok
# 62          The Magnetic Lady.txt.Jonson.tok
# 63                The New Inn.txt.Jonson.tok
# 64         The Staple of News.txt.Jonson.tok
# 65                    Volpone.txt.Jonson.tok
# 66                 ALL FOOLS.txt.Chapman.tok
# 67    AN HUMOROUS DAYS MIRTH.txt.Chapman.tok
# 68      BEGGAR OF ALEXANDRIA.txt.Chapman.tok
# 69             BUSSY DAMBOIS.txt.Chapman.tok
# 70            BYRONS TRAGEDY.txt.Chapman.tok
# 71                   May Day.txt.Chapman.tok
# 72           MONSIEUR DOLIVE.txt.Chapman.tok
# 73  REVENGE CF BUSSY DAMBOIS.txt.Chapman.tok
# 74                 sir_giles.txt.Chapman.tok
# 75       THE GENTLEMAN USHER.txt.Chapman.tok
# 76          THE WIDOWS TEARS.txt.Chapman.tok
#
# [77 rows x 13 columns]

# %% [markdown]
# ### Get Basic Features

# %%
def get_preds_imp(dataframe):
    
    """
    change function get_features_GM(train_data, test_data) for feature engineering!
    input: Dataframe
    
    output: predictions for test instances, and coefficient matrix, cls
    """
    
    instances= get_LOO_instances(dataframe)
    predictions=[]
    for inst in instances:
        train_data= inst[0]
        test_data = inst[1]
        train_label=train_data["Label"]
        train_features, test_features= get_features_GM_imp(train_data, test_data)
        pred, coeff, cls= predict(train_features, train_label, test_features)
        predictions.append(pred)
        
    return np.array(predictions), coeff, cls

# %%
def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_305"]
    X_POSstops = X_train[ "POSstops_305"]
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_305"]
    X_test_POSstops = X_test[ "POSstops_305"]
    
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_305, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii") #ngrams of POS/stops
    
    #cvec1 = CountVectorizer(vocabulary= stopwords_507, strip_accents="ascii")#word freq of stop words
    #cvec2 = CountVectorizer(max_features=1000, strip_accents="ascii") #freq of POS taggs
    #cvec3 = CountVectorizer(ngram_range=(2,2),max_features=1000, strip_accents="ascii") #ngrams of POS/stops 

    #fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
        ))

    
    return train_features, test_features

# %%
predictions, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_imp"]=predictions

# %%
df["acc_imp"] =df["Label"]==df[ "Pred_imp"]
acc_imp=df.loc[df.acc_imp== True, 'acc_imp'].count()/df.shape[0]
print(acc_imp)
# Out:
# 0.8181818181818182

# %%
#507 stop words
#0.8181818181818182

#305 stop words
#0.8181818181818182

# %% [markdown]
# ## Feature: Word Frequency

# %% [markdown]
# Add simple word frequency to the basic features rather than using it by itself as in the bag of words model.

# %%
#modified get_features function including word frequency

def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_305"]
    X_POSstops = X_train[ "POSstops_305"]
   
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_305"]
    X_test_POSstops = X_test[ "POSstops_305"]
    
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_305, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii") #ngrams of POS/stops
    
    cvec4 = CountVectorizer(strip_accents="ascii") 

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        cvec4.fit_transform(X_txt).toarray(),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            cvec4.transform(X_test_txt).toarray(),
        ))

    
    return train_features, test_features

# %%
predictions_word_freq, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_word_freq"]=predictions_word_freq

# %%
df["acc_word_freq"] =df["Label"]==df[ "Pred_word_freq"]
acc_word_freq=df.loc[df.acc_word_freq== True, 'acc_word_freq'].count()/df.shape[0]
print(acc_word_freq)
# Out:
# 0.8181818181818182

# %%
#507 stop words
#0.8181818181818182

#305 stop words
#0.8181818181818182

# %% [markdown]
# ## Feature: Keyword Extraction

# %% [markdown]
# Uses package RAKE (Rapid Automated Keyword Extraction) to extract keywords and key phrases from the text which can then be counted to form a feature vector.

# %%
"""Get set out of 1000 highest ranked keywords for each play saved in one single string"""

import RAKE
rake = RAKE.Rake(stopwords_305) #use stopwords with best results from before

all_keywords = []
punctuation = """!"',;:.-?)([]<>*#\n\t\r """

for text in df["Raw Text"]:
    keywords = ""
    text_keywords = rake.run(text.strip(punctuation))
    text_keywords = set([keywords[0] for keywords in sorted(text_keywords, key=lambda word: word[1])[:1000]])
    for keyword in text_keywords:
        keywords += keyword + " "
    
    all_keywords.append(keywords)

all_keywords = np.array(all_keywords)

# %%
#create column and save in df
df["Keywords"] = all_keywords

# %%
#modified get_features function including keywords

def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_305"]
    X_POSstops = X_train[ "POSstops_305"]
    X_key = X_train["Keywords"]
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_305"]
    X_test_POSstops = X_test[ "POSstops_305"]
    X_test_key = X_test["Keywords"]
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_305, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii", max_features=1000) #ngrams of POS/stops
    
    cvec4 = CountVectorizer(strip_accents="ascii") #keyword frequency

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        cvec4.fit_transform(X_key).toarray(),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            cvec4.transform(X_test_key).toarray(),
        ))

    
    return train_features, test_features

# %%
predictions_key, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_keywords"]=predictions_key

# %%
df["acc_keywords"] =df["Label"]==df[ "Pred_keywords"]
acc_keywords=df.loc[df.acc_keywords== True, 'acc_keywords'].count()/df.shape[0]
print(acc_keywords)
# Out:
# 0.8181818181818182

# %%
#507 stop words
#0.8051948051948052

#305 stop words
#0.8181818181818182

# %% [markdown]
# ## Feature: Frequency of Stemmed Words

# %% [markdown]
# Three different nltk stemmers were tested to add frequency of stemmed words as a feature.

# %%
"""Transform given play to a stemmed version and save in df"""

#three different nltk stemmers to be tested
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer

punctuation = """!"',;:.-?)([]<>*#\n\t\r """
all_stemmed_texts = []

lancaster = LancasterStemmer()
porter = PorterStemmer()
snowball = SnowballStemmer("english")

#change this to test different stemmers
#Porter works best (see results below)
stemmer = porter

for text in df["Raw Text"]:
    stemmed_text = ""
    for word in text.split():
        stemmed_text += stemmer.stem(word.strip(punctuation)) + " "
    
    all_stemmed_texts.append(stemmed_text)

all_stemmed_texts = np.array(all_stemmed_texts)

# %%
#save Stem column in df
df["Stems"] = all_stemmed_texts

# %%
#modified get_features function including stemmed words frequency

def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_305"]
    X_POSstops = X_train[ "POSstops_305"]
    X_stem = X_train["Stems"]
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_305"]
    X_test_POSstops = X_test[ "POSstops_305"]
    X_test_stem = X_test["Stems"]
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_305, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii", max_features = 1000) #ngrams of POS/stops 
    
    cvec4 = CountVectorizer()

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        cvec4.fit_transform(X_stem).toarray(),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            cvec4.transform(X_test_stem).toarray(),
        ))

    
    return train_features, test_features

# %%
predictions_stem, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_stems"]=predictions_stem

# %%
df["acc_stems"] =df["Label"]==df[ "Pred_stems"]
acc_stems=df.loc[df.acc_stems== True, 'acc_stems'].count()/df.shape[0]
print(acc_stems)
# Out:
# 0.8181818181818182

# %%
#507 stop words
#0.8181818181818182

#305 stop words
#0.8181818181818182

# %%
df
# Out:
#     Unnamed: 0  Play_id                                           Raw Text  \
# 0            0        0  As I remember , Adam , it was upon this fashio...
# 1            1        1  Proceed , Solinus , to procure my fall\nAnd by...
# 2            2        2  Who 's there ?\nNay , answer me : stand , and ...
# 3            3        3  So shaken as we are , so wan with care ,\nFind...
# 4            4        4  Open your ears ; for which of you will stop\nT...
# 5            5        5  O for a Muse of fire , that would ascend\nThe ...
# 6            6        6  Hung be the heavens with black , yield day to ...
# 7            7        7  As by your high imperial majesty\nI had in cha...
# 8            8        8  I wonder how the king escaped our hands .\nWhi...
# 9            9        9  Hence ! home , you idle creatures get you home...
# 10          10       10  Now , say , Chatillon , what would France with...
# 11          11       11  Let fame , that all hunt after in their lives ...
# 12          12       12  In sooth , I know not why I am so sad :\nIt we...
# 13          13       13  Sir Hugh , persuade me not ; I will make a Sta...
# 14          14       14  Now , fair Hippolyta , our nuptial hour\nDraws...
# 15          15       15  I learn in this letter that Don Peter of Arrag...
# 16          16       16  Old John of Gaunt , time-honour 'd Lancaster ,...
# 17          17       17  Now is the winter of our discontent\nMade glor...
# 18          18       18  Two households , both alike in dignity ,\nIn f...
# 19          19       19  I 'll pheeze you , in faith .\nA pair of stock...
# 20          20       20  Noble patricians , patrons of my right ,\nDefe...
# 21          21       21  If music be the food of love , play on ;\nGive...
# 22          22       22  Cease to persuade , my loving Proteus :\nHome-...
# 23          23       23  In delivering my son from me , I bury a second...
# 24          24       24  Nay , but this dotage of our general 's\nO'erf...
# 25          25       25  Before we proceed any further , hear me speak ...
# 26          26       26  You do not meet a man but frowns : our bloods\...
# 27          27       27  I come no more to make you laugh : things now ...
# 28          28       28  I thought the king had more affected the Duke ...
# 29          29       29  When shall we three meet again\nIn thunder , l...
# ..         ...      ...                                                ...
# 47          47       47  What Raynulph monk of Chester can\nRaise from ...
# 48          48       48  I am at my wit 's end , Savorwit .\nAnd I am e...
# 49          49       49  My lords ,\nKnow that we , far from any natura...
# 50          50       50  Thus high , my lords , your powers and constan...
# 51          51       51  My three years spent in war has now undone\nMy...
# 52          52       52  NOW o ' my Faith , Old Bishop Valen-\ntine ,\n...
# 53          53       53  such luck to spin out these fine things still ...
# 54          54       54  Sylla 's Ghost .\nDOst thou not feel me , Rome...
# 55          55       55  ' Tis I , blind Archer .\nWho ?\nMercury ?\nSt...
# 56          56       56  Brain-worm ,\nCall up your young master : bid ...
# 57          57       57  I Would , I could make 'hem a shew my self . I...
# 58          58       58  95\nP O E T A S T E R:\nO R,\nHis Arraignment ...
# 59          59       59  Thy worst .\nI fart at thee .\nHa' you your Wi...
# 60          60       60  YOU woful wights , give ear a\nwhile ,\nAnd ma...
# 61          61       61  To Earth ?\nand why to Earth , thou foolish\nS...
# 62          62       62  Welcome , good Captain Ironside , and Bro-\nth...
# 63          63       63  The SCENE\nB A R N E T.\nThe P E R S O N S of ...
# 64          64       64  he walks in his Gown , Wastcoat , and Trousers...
# 65          65       65  Open the Shrine , that I may see my Saint .\nH...
# 66          66       66  \nCan one self cause , in subjects so alike As...
# 67          67       67  An Humorous Day 's Mirth .\nLa , Yet hath the ...
# 68          68       68  \nLeave me awhile , my lords , and wait for me...
# 69          69       69  \nFortune , not Reason , rules the state of th...
# 70          70       70  Byron fall 'n in so traitorous a re - lapse , ...
# 71          71       71  Sc?na prima .\nof the first day . Loose no tim...
# 72          72       72  \nMonsieur D'Olive .\nPhilip , the Duke .\nAnn...
# 73          73       73  \nTo what will this declining kingdom turn , S...
# 74          74       74  VVhere is Sir Gyles Goosecappe here ?\nHere my...
# 75          75       75  \nHaste , nephew 1 what , a sluggard ?\nFie fo...
# 76          76       76  \nThou blind imperfect goddess , that delight ...
#
#                                               POS_new  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT ADP DET NOUN ...
# 1    PROPN PUNCT PROPN PUNCT PART VERB ADJ NOUN SP...
# 2    NOUN VERB PUNCT SPACE PROPN PUNCT VERB PUNCT ...
# 3    ADV VERB VERB PUNCT ADV NOUN ADP NOUN PUNCT S...
# 4    VERB ADJ NOUN PUNCT ADJ PRON VERB SPACE DET N...
# 5    INTJ DET PROPN NOUN PUNCT ADJ VERB SPACE DET ...
# 6    PROPN NOUN ADP ADJ PUNCT NOUN NOUN ADP NOUN P...
# 7    ADP ADP ADJ ADJ ADJ NOUN SPACE PRON NOUN ADJ ...
# 8    PRON VERB NOUN VERB ADJ NOUN PUNCT SPACE ADP ...
# 9    ADV PUNCT PUNCT PRON ADJ NOUN PRON PUNCT SPAC...
# 10   ADV PUNCT PUNCT PROPN PUNCT NOUN PROPN ADP PR...
# 11   VERB NOUN PUNCT ADP NOUN NOUN PUNCT SPACE PRO...
# 12   ADP NOUN PUNCT PRON ADV PRON ADV ADJ PUNCT SP...
# 13   PROPN PROPN PUNCT VERB ADV PUNCT PRON VERB DE...
# 14   ADV PUNCT ADJ PROPN PUNCT ADJ ADJ NOUN SPACE ...
# 15   PRON VERB DET NOUN ADJ PROPN PROPN PROPN SPAC...
# 16   PROPN PROPN PROPN PUNCT NOUN PUNCT NOUN PROPN...
# 17   ADV VERB NOUN ADJ NOUN SPACE VERB ADJ NOUN AD...
# 18   NUM NOUN PUNCT ADV NOUN PUNCT SPACE ADP ADJ P...
# 19   PRON VERB VERB PRON PUNCT NOUN PUNCT SPACE DE...
# 20   ADJ NOUN PUNCT NOUN ADJ PUNCT SPACE VERB NOUN...
# 21   ADP NOUN NOUN NOUN PUNCT VERB PART PUNCT SPAC...
# 22   VERB PART VERB PUNCT ADJ VERB PROPN PUNCT SPA...
# 23   ADP VERB ADJ NOUN PUNCT PRON VERB DET ADJ NOU...
# 24   INTJ PUNCT CCONJ DET NOUN ADJ NOUN PART SPACE...
# 25   ADP VERB DET ADV PUNCT VERB VERB PUNCT SPACE ...
# 26   PRON VERB ADV VERB DET NOUN CCONJ VERB PUNCT ...
# 27   PRON PART PRON VERB PUNCT NOUN PUNCT SPACE AD...
# 28   PRON VERB NOUN PROPN SPACE PROPN ADP PROPN PU...
# 29   ADV VERB SPACE ADP NOUN PUNCT NOUN PUNCT NOUN...
# ..                                                ...
# 47   NOUN PROPN NOUN PROPN SPACE PROPN ADJ SPACE A...
# 48   PRON ADJ NOUN PART PUNCT PROPN PUNCT SPACE CC...
# 49   ADJ NOUN PUNCT SPACE VERB ADP PUNCT ADV DET A...
# 50   ADV ADJ PUNCT ADJ NOUN PUNCT ADJ NOUN ADJ NOU...
# 51   ADJ NOUN VERB NOUN VERB SPACE ADJ NOUN ADV PU...
# 52   ADV INTJ PUNCT ADJ NOUN PUNCT PROPN PROPN PRO...
# 53   ADJ NOUN PART VERB PART ADJ NOUN PUNCT SPACE ...
# 54   PROPN PART PROPN PUNCT SPACE PROPN ADV VERB P...
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB PART ADJ ADJ...
# 57   PRON VERB PUNCT PRON VERB PUNCT VERB DET NOUN...
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...
# 59   PRON ADJ PUNCT SPACE PRON VERB PRON PUNCT SPA...
# 60   PRON ADJ NOUN PUNCT X DET SPACE PUNCT SPACE C...
# 61   ADP PROPN PUNCT SPACE ADP PROPN PUNCT ADJ SPA...
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT PROPN SPACE ...
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...
# 64   VERB ADJ PROPN PUNCT PROPN PUNCT PROPN PUNCT ...
# 65   VERB PROPN PUNCT ADP PRON VERB ADJ PROPN PUNC...
# 66   SPACE VERB PUNCT NOUN ADV ADV ADP PRON VERB P...
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...
# 68   SPACE VERB ADV PUNCT ADJ NOUN PUNCT VERB ADP ...
# 69   SPACE PROPN PUNCT ADV NOUN PUNCT VERB NOUN NO...
# 70   PROPN VERB PUNCT ADV ADJ DET PUNCT NOUN PUNCT...
# 71   NOUN NOUN PUNCT SPACE NOUN PUNCT ADJ NOUN NOU...
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT PRO...
# 73   SPACE ADP NOUN VERB DET VERB NOUN NOUN PUNCT ...
# 74   PROPN VERB PROPN PROPN PROPN ADV PUNCT SPACE ...
# 75   SPACE PROPN PUNCT NOUN NUM NOUN PUNCT DET ADJ...
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT DET NOUN PUNCT...
#
#                                          POSstops_new  Label         Author  \
# 0    ADP PRON VERB PUNCT PROPN PUNCT it was ADP DE...      0  E-Shakespeare
# 1    PROPN PUNCT PROPN PUNCT PART VERB ADJ NOUN SP...      0  E-Shakespeare
# 2    NOUN VERB there PUNCT SPACE PROPN PUNCT VERB ...      0  E-Shakespeare
# 3    ADV VERB as we VERB PUNCT ADV NOUN ADP NOUN P...      0  E-Shakespeare
# 4    VERB ADJ NOUN PUNCT for ADJ of PRON VERB stop...      0  E-Shakespeare
# 5    INTJ for DET PROPN of NOUN PUNCT ADJ would VE...      0  E-Shakespeare
# 6    PROPN be the NOUN ADP ADJ PUNCT NOUN NOUN ADP...      0  E-Shakespeare
# 7    ADP ADP ADJ ADJ ADJ NOUN SPACE PRON had in NO...      0  E-Shakespeare
# 8    PRON VERB how the NOUN VERB ADJ NOUN PUNCT SP...      0  E-Shakespeare
# 9    ADV PUNCT home PUNCT PRON ADJ NOUN get PRON h...      0  E-Shakespeare
# 10   ADV PUNCT say PUNCT PROPN PUNCT NOUN would PR...      0  E-Shakespeare
# 11   VERB NOUN PUNCT ADP all NOUN after in their N...      0  E-Shakespeare
# 12   ADP NOUN PUNCT PRON know ADV why PRON am ADV ...      0  E-Shakespeare
# 13   PROPN PROPN PUNCT VERB me ADV PUNCT PRON VERB...      0  E-Shakespeare
# 14   ADV PUNCT ADJ PROPN PUNCT ADJ ADJ NOUN SPACE ...      0  E-Shakespeare
# 15   PRON VERB in DET NOUN ADJ PROPN PROPN of PROP...      0  E-Shakespeare
# 16   PROPN PROPN of PROPN PUNCT NOUN PUNCT NOUN PR...      0  E-Shakespeare
# 17   ADV VERB the NOUN of ADJ NOUN SPACE VERB ADJ ...      0  E-Shakespeare
# 18   NUM NOUN PUNCT both ADV in NOUN PUNCT SPACE A...      0  E-Shakespeare
# 19   PRON VERB VERB PRON PUNCT in NOUN PUNCT SPACE...      0  E-Shakespeare
# 20   ADJ NOUN PUNCT NOUN of ADJ right PUNCT SPACE ...      0  E-Shakespeare
# 21   ADP NOUN be the NOUN of NOUN PUNCT VERB PART ...      0  E-Shakespeare
# 22   VERB PART VERB PUNCT ADJ VERB PROPN PUNCT SPA...      0  E-Shakespeare
# 23   ADP VERB ADJ NOUN from me PUNCT PRON VERB DET...      1  L-Shakespeare
# 24   INTJ PUNCT CCONJ DET NOUN of ADJ NOUN PART SP...      1  L-Shakespeare
# 25   ADP we VERB DET ADV PUNCT VERB me VERB PUNCT ...      1  L-Shakespeare
# 26   PRON VERB ADV VERB DET NOUN CCONJ VERB PUNCT ...      1  L-Shakespeare
# 27   PRON come no more PART make PRON VERB PUNCT N...      1  L-Shakespeare
# 28   PRON VERB the NOUN had more affected the PROP...      1  L-Shakespeare
# 29   ADV shall we three VERB again SPACE ADP NOUN ...      1  L-Shakespeare
# ..                                                ...    ...            ...
# 47   NOUN PROPN NOUN of PROPN can SPACE PROPN from...      3      Middleton
# 48   PRON am at ADJ NOUN PART end PUNCT PROPN PUNC...      3      Middleton
# 49   ADJ NOUN PUNCT SPACE VERB ADP we PUNCT ADV fr...      3      Middleton
# 50   ADV ADJ PUNCT ADJ NOUN PUNCT ADJ NOUN and ADJ...      3      Middleton
# 51   ADJ three NOUN VERB in NOUN has now VERB SPAC...      3      Middleton
# 52   ADV INTJ PUNCT ADJ NOUN PUNCT PROPN PROPN PRO...      4         Jonson
# 53   ADJ NOUN PART VERB PART these ADJ NOUN still ...      4         Jonson
# 54   PROPN PART PROPN PUNCT SPACE PROPN thou ADV V...      4         Jonson
# 55   PUNCT PROPN PRON PUNCT ADJ PROPN PUNCT SPACE ...      4         Jonson
# 56   NOUN PUNCT NOUN PUNCT SPACE VERB PART ADJ ADJ...      4         Jonson
# 57   PRON VERB PUNCT PRON VERB make PUNCT VERB DET...      4         Jonson
# 58   NUM SPACE NOUN NOUN NOUN NOUN NOUN NOUN NOUN ...      4         Jonson
# 59   PRON ADJ PUNCT SPACE PRON VERB at PRON PUNCT ...      4         Jonson
# 60   PRON ADJ NOUN PUNCT give X DET SPACE while PU...      4         Jonson
# 61   ADP PROPN PUNCT SPACE and why ADP PROPN PUNCT...      4         Jonson
# 62   INTJ PUNCT ADJ PROPN PROPN PUNCT and PROPN SP...      4         Jonson
# 63   DET PROPN SPACE PROPN DET NOUN NOUN NOUN PROP...      4         Jonson
# 64   he VERB in ADJ PROPN PUNCT PROPN PUNCT and PR...      4         Jonson
# 65   VERB the PROPN PUNCT ADP PRON VERB see ADJ PR...      4         Jonson
# 66   SPACE VERB one self cause PUNCT in NOUN ADV A...      5        Chapman
# 67   DET ADJ PROPN PART PROPN PUNCT SPACE PROPN PU...      5        Chapman
# 68   SPACE VERB me ADV PUNCT ADJ NOUN PUNCT and VE...      5        Chapman
# 69   SPACE PROPN PUNCT ADV NOUN PUNCT VERB the NOU...      5        Chapman
# 70   PROPN VERB PUNCT n in ADV ADJ DET re PUNCT NO...      5        Chapman
# 71   NOUN NOUN PUNCT SPACE of the first NOUN PUNCT...      5        Chapman
# 72   SPACE PROPN PROPN PUNCT SPACE PROPN PUNCT the...      5        Chapman
# 73   SPACE ADP NOUN VERB DET VERB NOUN NOUN PUNCT ...      5        Chapman
# 74   PROPN VERB PROPN PROPN PROPN ADV PUNCT SPACE ...      5        Chapman
# 75   SPACE PROPN PUNCT NOUN NUM NOUN PUNCT DET ADJ...      5        Chapman
# 76   SPACE PROPN ADJ ADJ NOUN PUNCT DET NOUN PUNCT...      5        Chapman
#
#                                         Play  Pred_imp  acc_imp  \
# 0          asyoulikeit.txt.E-Shakespeare.tok         0     True
# 1        comedy_errors.txt.E-Shakespeare.tok         0     True
# 2               Hamlet.txt.E-Shakespeare.tok         1    False
# 3         henryivPart1.txt.E-Shakespeare.tok         0     True
# 4         henryivPart2.txt.E-Shakespeare.tok         0     True
# 5               henryv.txt.E-Shakespeare.tok         0     True
# 6         henryviPart1.txt.E-Shakespeare.tok         0     True
# 7         henryviPart2.txt.E-Shakespeare.tok         0     True
# 8         henryviPart3.txt.E-Shakespeare.tok         2    False
# 9        julius_caesar.txt.E-Shakespeare.tok         0     True
# 10           King John.txt.E-Shakespeare.tok         0     True
# 11   Love_Labours_lost.txt.E-Shakespeare.tok         0     True
# 12     merchant-venice.txt.E-Shakespeare.tok         0     True
# 13         merry_wives.txt.E-Shakespeare.tok         0     True
# 14           midsummer.txt.E-Shakespeare.tok         0     True
# 15            much_ado.txt.E-Shakespeare.tok         0     True
# 16           richardii.txt.E-Shakespeare.tok         0     True
# 17          richardiii.txt.E-Shakespeare.tok         0     True
# 18        romeo_juliet.txt.E-Shakespeare.tok         0     True
# 19        taming_shrew.txt.E-Shakespeare.tok         0     True
# 20    Titus_Andronicus.txt.E-Shakespeare.tok         0     True
# 21       twelfth_night.txt.E-Shakespeare.tok         1    False
# 22       two_gentlemen.txt.E-Shakespeare.tok         0     True
# 23            allswell.txt.L-Shakespeare.tok         1     True
# 24           Cleopatra.txt.L-Shakespeare.tok         1     True
# 25          coriolanus.txt.L-Shakespeare.tok         1     True
# 26           Cymbeline.txt.L-Shakespeare.tok         1     True
# 27           henryviii.txt.L-Shakespeare.tok         1     True
# 28                Lear.txt.L-Shakespeare.tok         1     True
# 29             Macbeth.txt.L-Shakespeare.tok         1     True
# ..                                       ...       ...      ...
# 47                 hengist.txt.Middleton.tok         3     True
# 48                  no wit.txt.Middleton.tok         0    False
# 49                 Phoenix.txt.Middleton.tok         3     True
# 50       the second maiden.txt.Middleton.tok         3     True
# 51               the witch.txt.Middleton.tok         3     True
# 52            A Tale of a Tub.txt.Jonson.tok         4     True
# 53            Bartholmew Fair.txt.Jonson.tok         4     True
# 54    Catiline His Conspiracy.txt.Jonson.tok         4     True
# 55            Cynthias Revels.txt.Jonson.tok         4     True
# 56    Every Man in his Humour.txt.Jonson.tok         4     True
# 57              Love_Restored.txt.Jonson.tok         1    False
# 58                  Poetaster.txt.Jonson.tok         4     True
# 59              The Alchemist.txt.Jonson.tok         4     True
# 60        THE CASE IS ALTERED.txt.Jonson.tok         1    False
# 61        The Devil is an Ass.txt.Jonson.tok         4     True
# 62          The Magnetic Lady.txt.Jonson.tok         4     True
# 63                The New Inn.txt.Jonson.tok         4     True
# 64         The Staple of News.txt.Jonson.tok         4     True
# 65                    Volpone.txt.Jonson.tok         4     True
# 66                 ALL FOOLS.txt.Chapman.tok         5     True
# 67    AN HUMOROUS DAYS MIRTH.txt.Chapman.tok         5     True
# 68      BEGGAR OF ALEXANDRIA.txt.Chapman.tok         5     True
# 69             BUSSY DAMBOIS.txt.Chapman.tok         5     True
# 70            BYRONS TRAGEDY.txt.Chapman.tok         5     True
# 71                   May Day.txt.Chapman.tok         5     True
# 72           MONSIEUR DOLIVE.txt.Chapman.tok         5     True
# 73  REVENGE CF BUSSY DAMBOIS.txt.Chapman.tok         5     True
# 74                 sir_giles.txt.Chapman.tok         5     True
# 75       THE GENTLEMAN USHER.txt.Chapman.tok         5     True
# 76          THE WIDOWS TEARS.txt.Chapman.tok         5     True
#
#     Pred_word_freq  acc_word_freq  \
# 0                0           True
# 1                0           True
# 2                1          False
# 3                0           True
# 4                0           True
# 5                0           True
# 6                2          False
# 7                0           True
# 8                2          False
# 9                1          False
# 10               0           True
# 11               0           True
# 12               0           True
# 13               0           True
# 14               0           True
# 15               0           True
# 16               0           True
# 17               0           True
# 18               0           True
# 19               0           True
# 20               0           True
# 21               0           True
# 22               0           True
# 23               1           True
# 24               1           True
# 25               1           True
# 26               1           True
# 27               1           True
# 28               1           True
# 29               1           True
# ..             ...            ...
# 47               3           True
# 48               3           True
# 49               3           True
# 50               3           True
# 51               3           True
# 52               4           True
# 53               4           True
# 54               4           True
# 55               4           True
# 56               4           True
# 57               4           True
# 58               4           True
# 59               4           True
# 60               1          False
# 61               4           True
# 62               4           True
# 63               4           True
# 64               4           True
# 65               4           True
# 66               5           True
# 67               5           True
# 68               5           True
# 69               5           True
# 70               5           True
# 71               5           True
# 72               5           True
# 73               5           True
# 74               5           True
# 75               5           True
# 76               5           True
#
#                                              Keywords  Pred_keywords  \
# 0   dear rose enemy value avoid nature trust thee ...              0
# 1   saddler welcome falsehood wench nature marvel ...              0
# 2   enemy constantly welcome advantage avoid marve...              1
# 3   enemy plant advantage falsehood nature looked ...              0
# 4   enemy holy old northumberland nature owed look...              0
# 5   assume highness claiming admit quickly absence...              0
# 6   advantage speech marvel pair idly quickly scat...              2
# 7   dowry enemy speech welcome avoid pair marvel q...              0
# 8   toss s bird cleft abide fair fell clifford pri...              2
# 9   months welcome avoid nature o cicero threw con...              0
# 10  enemy hedged advantage welcome nature respecti...              0
# 11  dowry loving kiss welcome falsehood wench look...              0
# 12  months tripolis advantage value hedged scatter...              0
# 13  boarded bounty host o abide tinderbox threw qu...              0
# 14  cowslip welcome nun marvel courageously merry ...              0
# 15  boarded love-gods welcome looked cleft padua w...              0
# 16  consequently enemy advantage welcome avoid nat...              0
# 17  enemy months welcome stabb nature weeping meed...              0
# 18  welcome falsehood speech pair looked d april t...              0
# 19  dowry welcome wench pair nature idly padua fai...              0
# 20  welcome styga nature begg fair peace readiness...              0
# 21  enemy welcome wench speech lasting marvel cool...              1
# 22  welcome bounty pair concord meed weeping absen...              0
# 23  enemy gentry advantage welcome months suspecte...              1
# 24  childishness welcome speech nature breeding re...              1
# 25  maliciously mail welcome value enemy nature lo...              1
# 26  enemy tabled suspected avoid looked value abid...              1
# 27  confession gentry advantage speech welcome nat...              1
# 28  enemy plant dowry speech avoid mingled marvel ...              1
# 29  welcome nature owed quickly thick night sin fa...              1
# ..                                                ...            ...
# 47  lanthorns afflictions advantage bounty holy na...              3
# 48  toss dowry enemy welcome wench months nature t...              0
# 49  enemy gentry advantage wench welcome nature ab...              3
# 50  enemy afflictions advantage value falsehood na...              3
# 51  oh mother enemy months roofs welcome wench pai...              3
# 52  pancrace ore afore welcome value nature pair b...              4
# 53  enemy afore hours running loud ones delicate m...              4
# 54  enemy afore ensigns prais nature cleft ashes f...              4
# 55  speech suspected prais pair nature threw symme...              4
# 56  afore gentry radish inhabit pair nature abide ...              4
# 57  ensigns value avoid musician ras breeding habi...              1
# 58  emblems welcome suspected prais nature idly ab...              4
# 59  months wench marvel pair nature quickly yes fa...              4
# 60  months advantage value wench marvel respective...              1
# 61  months welcome wench bounty pair nature ensign...              4
# 62  gills enemy afore welcome bounty value pair na...              4
# 63  welcome wench avoid pair nature mingled breedi...              4
# 64  ambler place worth welcome bounty value pair e...              4
# 65  toss maliciously months roofs welcome speech a...              4
# 66  months speech wench plant idly respective welc...              5
# 67  neversaw welcome wench nature abide lemot admi...              5
# 68  osiris months welcome beauteous nymphs fine we...              5
# 69  holy welcome value avoid nature bounty daily s...              5
# 70  enemy ensigns welcome bounty ingratitude crack...              5
# 71  afore howre shunne wench nature open streets a...              5
# 72  enflamed speech bounty assume idly welcome tap...              5
# 73  dear blood speech falsehood roofs nature stabb...              5
# 74  blowe healthfully wench welcome afore nature a...              5
# 75  toss enemy welcome wench speech sweep care lim...              5
# 76  gentry butgeneral welcome 315 nature incontine...              5
#
#     acc_keywords                                              Stems  \
# 0           True  As I rememb  adam  it wa upon thi fashion bequ...
# 1           True  proce  solinu  to procur my fall and by the do...
# 2          False  who s there  nay  answer me  stand  and unfold...
# 3           True  So shaken as we are  so wan with care  find we...
# 4           True  open your ear  for which of you will stop the ...
# 5           True  O for a muse of fire  that would ascend the br...
# 6          False  hung be the heaven with black  yield day to ni...
# 7           True  As by your high imperi majesti I had in charg ...
# 8          False  I wonder how the king escap our hand  while we...
# 9           True  henc  home  you idl creatur get you home  Is t...
# 10          True  now  say  chatillon  what would franc with us ...
# 11          True  let fame  that all hunt after in their live  l...
# 12          True  In sooth  I know not whi I am so sad  It weari...
# 13          True  sir hugh  persuad me not  I will make a star c...
# 14          True  now  fair hippolyta  our nuptial hour draw on ...
# 15          True  I learn in thi letter that don peter of arrago...
# 16          True  old john of gaunt  time-honour d lancast  hast...
# 17          True  now is the winter of our discont made gloriou ...
# 18          True  two household  both alik in digniti  In fair v...
# 19          True  I ll pheez you  in faith  A pair of stock  you...
# 20          True  nobl patrician  patron of my right  defend the...
# 21         False  If music be the food of love  play on  give me...
# 22          True  ceas to persuad  my love proteu  home-keep you...
# 23          True  In deliv my son from me  I buri a second husba...
# 24          True  nay  but thi dotag of our gener s o'erflow the...
# 25          True  befor we proceed ani further  hear me speak  s...
# 26          True  you do not meet a man but frown  our blood No ...
# 27          True  I come no more to make you laugh  thing now  t...
# 28          True  I thought the king had more affect the duke of...
# 29          True  when shall we three meet again In thunder  lig...
# ..           ...                                                ...
# 47          True  what raynulph monk of chester can rais from hi...
# 48         False  I am at my wit s end  savorwit  and I am ev'n ...
# 49          True  My lord  know that we  far from ani natur prid...
# 50          True  thu high  my lord  your power and constant lov...
# 51          True  My three year spent in war ha now undon My pea...
# 52          True  now o  my faith  old bishop valen tine  you ha...
# 53          True  such luck to spin out these fine thing still  ...
# 54          True  sylla s ghost  dost thou not feel me  rome  no...
# 55          True   ti I  blind archer  who  mercuri  stay  cupid...
# 56          True  brain-worm  call up your young master  bid him...
# 57         False  I would  I could make hem a shew my self  In t...
# 58          True  95 P O E T A S T E R O R hi arraign  A comic s...
# 59          True  thi worst  I fart at thee  Ha you your wit  wh...
# 60         False  you woful wight  give ear a while  and mark th...
# 61          True  To earth  and whi to earth  thou foolish spiri...
# 62          True  welcom  good captain ironsid  and bro ther  yo...
# 63          True  the scene B A R N E T the P E R S O N S of the...
# 64          True  he walk in hi gown  wastcoat  and trouser  exp...
# 65          True  open the shrine  that I may see my saint  hail...
# 66          True  can one self caus  in subject so alik As you t...
# 67          True  An humor day s mirth  La  yet hath the morn sp...
# 68          True  leav me awhil  my lord  and wait for me At the...
# 69          True  fortun  not reason  rule the state of thing  r...
# 70          True  byron fall n in so traitor a re  laps  alleg f...
# 71          True  sc?na prima  of the first day  loos no time bl...
# 72          True  monsieur d'oliv  philip  the duke  ann  count ...
# 73          True  To what will thi declin kingdom turn  swindg i...
# 74          True  vvhere is sir gyle goosecapp here  here my lor...
# 75          True  hast  nephew 1 what  a sluggard  fie for shame...
# 76          True  thou blind imperfect goddess  that delight st ...
#
#     Pred_stems  acc_stems
# 0            0       True
# 1            0       True
# 2            1      False
# 3            0       True
# 4            0       True
# 5            0       True
# 6            2      False
# 7            0       True
# 8            2      False
# 9            0       True
# 10           0       True
# 11           0       True
# 12           0       True
# 13           4      False
# 14           0       True
# 15           0       True
# 16           0       True
# 17           0       True
# 18           0       True
# 19           0       True
# 20           0       True
# 21           0       True
# 22           0       True
# 23           1       True
# 24           1       True
# 25           1       True
# 26           1       True
# 27           1       True
# 28           1       True
# 29           1       True
# ..         ...        ...
# 47           3       True
# 48           3       True
# 49           3       True
# 50           3       True
# 51           3       True
# 52           4       True
# 53           4       True
# 54           4       True
# 55           4       True
# 56           4       True
# 57           4       True
# 58           4       True
# 59           4       True
# 60           1      False
# 61           4       True
# 62           4       True
# 63           4       True
# 64           4       True
# 65           4       True
# 66           5       True
# 67           5       True
# 68           5       True
# 69           5       True
# 70           5       True
# 71           5       True
# 72           5       True
# 73           5       True
# 74           5       True
# 75           5       True
# 76           5       True
#
# [77 rows x 18 columns]

# %% [markdown]
# ## Feature: Line Length

# %% [markdown]
# A structural feature representing the frequency of all occurring line lengths.
# Seems to make the classification a lot worse.

# %%
#save lengths as list

all_linelengths = []
max_line_length = max([len(text.split('\n')) for text in df["Raw Text"]])

for text in df["Raw Text"]:
    line_lengths_list = []
    
    for line in text.split('\n'):
        line_lengths_list.append(len(line))
    for remain_lines in range(max_line_length - len(line_lengths_list)):
        line_lengths_list.append(0)
    
    all_linelengths.append(line_lengths_list)

# %%
df["Line Length"] = all_linelengths

# %%
#modified get_features function including line lengths

def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_new"]
    X_POSstops = X_train[ "POSstops_new"]
    X_lines = list(X_train["Line Length"])
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_new"]
    X_test_POSstops = X_test[ "POSstops_new"]
    X_test_lines = list(X_test["Line Length"])
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_507, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii", max_features = 1000) #ngrams of POS/stops 

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        np.asarray(X_lines),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            np.asarray(X_test_lines),
        ))

    
    return train_features, test_features

# %%
predictions_lines, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_lines"]=predictions_lines

# %%
df["acc_lines"] =df["Label"]==df[ "Pred_lines"]
acc_lines=df.loc[df.acc_lines== True, 'acc_lines'].count()/df.shape[0]
print(acc_lines)
# Out:
# 0.6883116883116883

# %% [markdown]
# ## Feature: Sentence Length

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer

tok = PunktSentenceTokenizer()
all_sent_lengths = []
max_sent_length = max([len(tok.sentences_from_text(text)) for text in df["Raw Text"]])

                       
for text in df["Raw Text"]:
    sent_lengths = []
    for sent in tok.sentences_from_text(text):
        sent_lengths.append(len(sent))
    for remain_sents in range(max_sent_length - len(sent_lengths)):
        sent_lengths.append(0)  
    
    all_sent_lengths.append(sent_lengths)

# %%
df["Sent Length"] = all_sent_lengths

# %%
#modified get_features function including line lengths

def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_new"]
    X_POSstops = X_train[ "POSstops_new"]
    X_sent = list(X_train["Sent Length"])
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_new"]
    X_test_POSstops = X_test[ "POSstops_new"]
    X_test_sent = list(X_test["Sent Length"])
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_507, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii") #ngrams of POS/stops 

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        np.asarray(X_sent),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            np.asarray(X_test_sent),
        ))

    
    return train_features, test_features

# %%
predictions_sent, coeff, cls =  get_preds_imp(df)

# %%
df["Pred_sent"]=predictions_sent

# %%
df["acc_sent"] =df["Label"]==df[ "Pred_sent"]
acc_sent=df.loc[df.acc_sent== True, 'acc_sent'].count()/df.shape[0]
print(acc_sent)
# Out:
# 0.44155844155844154

# %% [markdown]
# ## Feature: Frequency of Lemmatized Words

# %% [markdown]
# Lemmas of words are already to be found in the df (generated with spacy).

# %%
#modified get_features function including lemma frequency


def get_features_GM_imp(X_train, X_test):
    
    """
    Input: data used to get model (created with the LOO function), both for testing and training
    output: features for train and test instances 
    """
    
    #getting the columns I want to use for my features from the instances passed
    X_txt = X_train["Raw Text"]
    X_POS = X_train["POS_305"]
    X_POSstops = X_train[ "POSstops_305"]
    X_lemmas = X_train["Lemmas"]
    
    X_test_txt= X_test["Raw Text"]
    X_test_POS = X_test["POS_305"]
    X_test_POSstops = X_test[ "POSstops_305"]
    X_test_lemmas = X_test["Lemmas"]
    
    # using countvectorizors to get freqs 
    cvec1 = CountVectorizer(vocabulary = stopwords_305, strip_accents="ascii")#word freq of stop words
    cvec2 = CountVectorizer() #freq of POS tags
    
    #add max_feature=1000 to get different results
    cvec3 = CountVectorizer(ngram_range=(2,2), strip_accents="ascii", max_features = 1000) #ngrams of POS/stops 
    
    cvec4 = CountVectorizer(strip_accents="ascii")

   # fitting  and transforming of train data, and stack vectors at the same time to get X for model
    train_features= np.hstack((
        cvec1.fit_transform(X_txt).toarray(),
        cvec2.fit_transform(X_POS).toarray(),
        cvec3.fit_transform(X_POSstops).toarray(),
        cvec4.fit_transform(X_lemmas).toarray(),
        
        ))
    
    #only fit X_test data
    test_features = np.hstack((
            cvec1.transform(X_test_txt).toarray(),
            cvec2.transform(X_test_POS).toarray(),
            cvec3.transform(X_test_POSstops).toarray(),
            cvec4.transform(X_test_lemmas).toarray(),
        ))

    
    return train_features, test_features

# %%
predictions_lemmas, coeff, cls =  get_preds_imp(df)
# Out:
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/joceline/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df["Pred_lemmas"]=predictions_lemmas

# %%
df["acc_lemmas"] =df["Label"]==df[ "Pred_lemmas"]
acc_lemmas=df.loc[df.acc_lemmas== True, 'acc_lemmas'].count()/df.shape[0]
print(acc_lemmas)
# Out:
# 0.8181818181818182

# %%
#507 stop words
#0.8051948051948052

#305 stop words
#0.8181818181818182
